# %% [markdown]
# convert .mp3 to .wav
# #terminal commands
#
# for f in *.mp3; do ffmpeg -i "$f" -acodec pcm_s16le -ac 1 -ar 16000 "${f%.mps}.wav"; done
# mkdir clips_wav
# find . -name '*.wav' | xargs mv --target-directory=clips_wav
#
# <!-- -ac 1 converts to mono channel -->
# <!-- -ar 16000 sets sampling rate to 16kHz -->

# %%
import itertools
import pandas as pd
import re
import subprocess

# %%
train = pd.read_csv('datasets/cv-corpus-9.0-2022-04-27/sw/train.tsv', sep='\t')
dev = pd.read_csv('datasets/cv-corpus-9.0-2022-04-27/sw/dev.tsv', sep='\t')
test = pd.read_csv('datasets/cv-corpus-9.0-2022-04-27/sw/test.tsv', sep='\t')
validated = pd.read_csv('datasets/cv-corpus-9.0-2022-04-27/sw/validated.tsv', sep='\t')
# Out:
# /home/ks/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Identifying sentencces in the training sets that have repetition, for development of our gold, silver and bronze standard dataset settings

# %%
# sentences_dict = dict.fromkeys(train['sentence'].tolist(), [])
sent_sets = []
for idx, value in train['sentence'].items():
    for idx2, value2 in validated['sentence'].items():
        if value == value2:
            sent_sets.append((idx,idx2))

# %%
duplicates = dict.fromkeys(train.index, [])

# %%
for (a,b) in sent_sets:
    duplicates[a] = duplicates[a] + [b]

# %%
gold = []
silver = []
bronze = []

for dups in duplicates.values():
    gold.append(dups[0:1])
    silver.append(dups[0:2])
    bronze.append(dups[0:3])

# %%
gold = [item for sublist in gold for item in sublist]
silver = [item for sublist in silver for item in sublist]
bronze = [item for sublist in bronze for item in sublist]

# %%
regex = re.compile(r'(File Size *:) ([\d|\.]*)')
size = []
for index in bronze:
    prop = subprocess.run(["soxi", "/media/ks/Elements/cv-corpus-9.0-2022-04-27/sw/clips/clips_wav/" + validated.iloc[index]['path'] + ".wav"], text=True, capture_output=True)
    size.append([index,regex.search(str(prop)).group(2)])

# %%
audio_sizes = pd.DataFrame(size)
audio_sizes = audio_sizes.set_index(0)

# %%
bronze_df = pd.concat([validated.loc[bronze],audio_sizes], axis=1)
bronze_df['path'] = bronze_df['path'].str[:-4] + '.wav'
bronze_df['path'] = '/media/ks/Elements/cv-corpus-9.0-2022-04-27/sw/clips/clips_wav/' + bronze_df['path']
bronze_df = bronze_df[['path', 1, 'sentence']]
bronze_df.columns = ['wav_filename', 'wav_filesize', 'transcript']
bronze_df['wav_filesize'] = bronze_df['wav_filesize'].astype(float).astype(int)

# %%
bronze_df.to_csv('bronze_standard.csv', index=False, line_terminator='\n')

# %%
silver_df = pd.concat([validated.loc[silver],audio_sizes.loc[silver]], axis=1)
silver_df['path'] = silver_df['path'].str[:-4] + '.wav'
silver_df['path'] = '/media/ks/Elements/cv-corpus-9.0-2022-04-27/sw/clips/clips_wav/' + silver_df['path']
silver_df = silver_df[['path', 1, 'sentence']]
silver_df.columns = ['wav_filename', 'wav_filesize', 'transcript']
silver_df['wav_filesize'] = silver_df['wav_filesize'].astype(float).astype(int)

# %%
silver_df.to_csv('silver_standard.csv', index=False)

# %%
gold_df = pd.concat([validated.loc[gold],audio_sizes.loc[gold]], axis=1)
gold_df['path'] = gold_df['path'].str[:-4] + '.wav'
gold_df['path'] = '/media/ks/Elements/cv-corpus-9.0-2022-04-27/sw/clips/clips_wav/' + gold_df['path']
gold_df = gold_df[['path', 1, 'sentence']]
gold_df.columns = ['wav_filename', 'wav_filesize', 'transcript']
gold_df['wav_filesize'] = gold_df['wav_filesize'].astype(float).astype(int)

# %%
gold_df.to_csv('gold_standard.csv', index=False)

# %% [markdown]
# data prep for dev and test sets

# %%
regex = re.compile(r'(File Size *:) ([\d|\.]*)')
size = []
for file_name in test['path']:
#     print(file_name[:-4])
    prop = subprocess.run(["soxi", "/media/ks/Elements/cv-corpus-9.0-2022-04-27/sw/clips/clips_wav/" + file_name[:-4] + ".wav"], text=True, capture_output=True)
    size.append(regex.search(str(prop)).group(2))

# %%
sizes = pd.DataFrame(size)
test_df = pd.concat([test,sizes], axis=1)
test_df['path'] = test_df['path'].str[:-4] + '.wav'
test_df['path'] = '/media/ks/Elements/cv-corpus-9.0-2022-04-27/sw/clips/clips_wav/' + test_df['path']
test_df = test_df[['path', 0, 'sentence']]
test_df.columns = ['wav_filename', 'wav_filesize', 'transcript']
test_df['wav_filesize'] = test_df['wav_filesize'].astype(float).astype(int)

# %%
test_df.to_csv('test_df.csv', index=False)

# %%
regex = re.compile(r'(File Size *:) ([\d|\.]*)')
size = []
for file_name in dev['path']:
    prop = subprocess.run(["soxi", "/media/ks/Elements/cv-corpus-9.0-2022-04-27/sw/clips/clips_wav/" + file_name + ".wav"], text=True, capture_output=True)
    size.append(regex.search(str(prop)).group(2))

# %%
sizes = pd.DataFrame(size)
dev_df = pd.concat([dev,sizes], axis=1)
dev_df['path'] = dev_df['path'].str[:-4] + '.wav'
dev_df['path'] = '/media/ks/Elements/cv-corpus-9.0-2022-04-27/sw/clips/clips_wav/' + dev_df['path']
dev_df = dev_df[['path', 0, 'sentence']]
dev_df.columns = ['wav_filename', 'wav_filesize', 'transcript']
dev_df['wav_filesize'] = dev_df['wav_filesize'].astype(float).astype(int)

# %%
dev_df.to_csv('dev_df.csv', index=False)

# %% [markdown]
# rough work below...

# %%
# create list of all mp3 files in bronze for conversion to .wav
' '.join(validated.loc[bronze]['path'].tolist())
# Out:
# 'common_voice_sw_28704519.mp3 common_voice_sw_28704530.mp3 common_voice_sw_28812149.mp3 common_voice_sw_28704537.mp3 common_voice_sw_28815583.mp3 common_voice_sw_28704542.mp3 common_voice_sw_28817743.mp3 common_voice_sw_28704543.mp3 common_voice_sw_28815944.mp3 common_voice_sw_28704552.mp3 common_voice_sw_28812161.mp3 common_voice_sw_28704555.mp3 common_voice_sw_28704556.mp3 common_voice_sw_28875936.mp3 common_voice_sw_28704557.mp3 common_voice_sw_28704586.mp3 common_voice_sw_28815498.mp3 common_voice_sw_28704588.mp3 common_voice_sw_28704591.mp3 common_voice_sw_28813395.mp3 common_voice_sw_28704593.mp3 common_voice_sw_28704689.mp3 common_voice_sw_28815786.mp3 common_voice_sw_28704691.mp3 common_voice_sw_28817732.mp3 common_voice_sw_28704692.mp3 common_voice_sw_28814976.mp3 common_voice_sw_28704693.mp3 common_voice_sw_28813284.mp3 common_voice_sw_28704704.mp3 common_voice_sw_29790864.mp3 common_voice_sw_29790865.mp3 common_voice_sw_29790911.mp3 common_voice_sw_29790899.mp3 common_voice_sw_29790913.mp3 common_voice_sw_29790958.mp3 common_voice_sw_30109419.mp3 common_voice_sw_29790915.mp3 common_voice_sw_29915851.mp3 common_voice_sw_29790918.mp3 common_voice_sw_29922388.mp3 common_voice_sw_29790937.mp3 common_voice_sw_29916169.mp3 common_voice_sw_29790938.mp3 common_voice_sw_29916466.mp3 common_voice_sw_29790939.mp3 common_voice_sw_29920689.mp3 common_voice_sw_29790940.mp3 common_voice_sw_29924348.mp3 common_voice_sw_31327570.mp3 common_voice_sw_29790941.mp3 common_voice_sw_29915754.mp3 common_voice_sw_29790970.mp3 common_voice_sw_29790978.mp3 common_voice_sw_29922542.mp3 common_voice_sw_29790980.mp3 common_voice_sw_29790981.mp3 common_voice_sw_29921731.mp3 common_voice_sw_29790998.mp3 common_voice_sw_29914384.mp3 common_voice_sw_29791000.mp3 common_voice_sw_29922233.mp3 common_voice_sw_29791002.mp3 common_voice_sw_29791004.mp3 common_voice_sw_29922564.mp3 common_voice_sw_29791028.mp3 common_voice_sw_29791031.mp3 common_voice_sw_29922066.mp3 common_voice_sw_29791036.mp3 common_voice_sw_29920676.mp3 common_voice_sw_29791067.mp3 common_voice_sw_29922567.mp3 common_voice_sw_29791069.mp3 common_voice_sw_29791070.mp3 common_voice_sw_29922036.mp3 common_voice_sw_29791073.mp3 common_voice_sw_29791086.mp3 common_voice_sw_29924085.mp3 common_voice_sw_29791094.mp3 common_voice_sw_29791096.mp3 common_voice_sw_29791118.mp3 common_voice_sw_29791119.mp3 common_voice_sw_29913080.mp3 common_voice_sw_29791137.mp3 common_voice_sw_29912738.mp3 common_voice_sw_29791146.mp3 common_voice_sw_29921531.mp3 common_voice_sw_29791151.mp3 common_voice_sw_29791170.mp3 common_voice_sw_29791173.mp3 common_voice_sw_29791174.mp3 common_voice_sw_29914361.mp3 common_voice_sw_29791175.mp3 common_voice_sw_29791263.mp3 common_voice_sw_29791176.mp3 common_voice_sw_29924392.mp3 common_voice_sw_29791192.mp3 common_voice_sw_29913038.mp3 common_voice_sw_29791195.mp3 common_voice_sw_29791196.mp3 common_voice_sw_29920836.mp3 common_voice_sw_29791203.mp3 common_voice_sw_29791259.mp3 common_voice_sw_29791204.mp3 common_voice_sw_29791205.mp3 common_voice_sw_29791206.mp3 common_voice_sw_30377471.mp3 common_voice_sw_29791213.mp3 common_voice_sw_29912997.mp3 common_voice_sw_29791217.mp3 common_voice_sw_29922565.mp3 common_voice_sw_29791221.mp3 common_voice_sw_29791228.mp3 common_voice_sw_29924057.mp3 common_voice_sw_29791234.mp3 common_voice_sw_29791237.mp3 common_voice_sw_29791244.mp3 common_voice_sw_29922276.mp3 common_voice_sw_29791246.mp3 common_voice_sw_29791254.mp3 common_voice_sw_29791247.mp3 common_voice_sw_29915939.mp3 common_voice_sw_29791248.mp3 common_voice_sw_29923144.mp3 common_voice_sw_29791252.mp3 common_voice_sw_29791255.mp3 common_voice_sw_29922275.mp3 common_voice_sw_29791256.mp3 common_voice_sw_29791306.mp3 common_voice_sw_29791262.mp3 common_voice_sw_30341384.mp3 common_voice_sw_29791264.mp3 common_voice_sw_29791229.mp3 common_voice_sw_29791267.mp3 common_voice_sw_29791268.mp3 common_voice_sw_29921296.mp3 common_voice_sw_29791280.mp3 common_voice_sw_29791249.m ...

# %%
# create list of all mp3 files in dev and test for conversion to .wav
# ' '.join(dev['path'].tolist())
' '.join(test['path'].tolist())
# Out:
# 'common_voice_sw_29002392.mp3 common_voice_sw_31292754.mp3 common_voice_sw_30612341.mp3 common_voice_sw_31291248.mp3 common_voice_sw_31295894.mp3 common_voice_sw_28581699.mp3 common_voice_sw_30667303.mp3 common_voice_sw_30342543.mp3 common_voice_sw_31229192.mp3 common_voice_sw_30644559.mp3 common_voice_sw_30621784.mp3 common_voice_sw_31384593.mp3 common_voice_sw_30644508.mp3 common_voice_sw_30644154.mp3 common_voice_sw_30644782.mp3 common_voice_sw_31414750.mp3 common_voice_sw_28266617.mp3 common_voice_sw_31291434.mp3 common_voice_sw_30577673.mp3 common_voice_sw_31081002.mp3 common_voice_sw_28261304.mp3 common_voice_sw_30562357.mp3 common_voice_sw_30563098.mp3 common_voice_sw_30642167.mp3 common_voice_sw_30644575.mp3 common_voice_sw_30562189.mp3 common_voice_sw_31306454.mp3 common_voice_sw_30620847.mp3 common_voice_sw_30644808.mp3 common_voice_sw_31292777.mp3 common_voice_sw_31152268.mp3 common_voice_sw_30386544.mp3 common_voice_sw_30623659.mp3 common_voice_sw_31255561.mp3 common_voice_sw_31087701.mp3 common_voice_sw_30642182.mp3 common_voice_sw_28765289.mp3 common_voice_sw_30645958.mp3 common_voice_sw_30631737.mp3 common_voice_sw_30644700.mp3 common_voice_sw_29159151.mp3 common_voice_sw_31308249.mp3 common_voice_sw_29162779.mp3 common_voice_sw_30605748.mp3 common_voice_sw_28660506.mp3 common_voice_sw_30659090.mp3 common_voice_sw_30623588.mp3 common_voice_sw_30385131.mp3 common_voice_sw_31292137.mp3 common_voice_sw_31290841.mp3 common_voice_sw_31290869.mp3 common_voice_sw_30621004.mp3 common_voice_sw_30621217.mp3 common_voice_sw_30731088.mp3 common_voice_sw_30731090.mp3 common_voice_sw_28929603.mp3 common_voice_sw_28929768.mp3 common_voice_sw_30623861.mp3 common_voice_sw_30623864.mp3 common_voice_sw_31217885.mp3 common_voice_sw_31466540.mp3 common_voice_sw_31256063.mp3 common_voice_sw_30617543.mp3 common_voice_sw_30617544.mp3 common_voice_sw_28581273.mp3 common_voice_sw_28581276.mp3 common_voice_sw_28813912.mp3 common_voice_sw_28813913.mp3 common_voice_sw_30632152.mp3 common_voice_sw_30632153.mp3 common_voice_sw_31291104.mp3 common_voice_sw_31292319.mp3 common_voice_sw_28245620.mp3 common_voice_sw_28245622.mp3 common_voice_sw_30624193.mp3 common_voice_sw_30624195.mp3 common_voice_sw_30658609.mp3 common_voice_sw_30658796.mp3 common_voice_sw_30628444.mp3 common_voice_sw_30629525.mp3 common_voice_sw_30630609.mp3 common_voice_sw_30631357.mp3 common_voice_sw_28259061.mp3 common_voice_sw_28259063.mp3 common_voice_sw_30628997.mp3 common_voice_sw_30629478.mp3 common_voice_sw_30718000.mp3 common_voice_sw_30718461.mp3 common_voice_sw_31229356.mp3 common_voice_sw_31229408.mp3 common_voice_sw_30574458.mp3 common_voice_sw_30574459.mp3 common_voice_sw_30628128.mp3 common_voice_sw_30628243.mp3 common_voice_sw_30620974.mp3 common_voice_sw_30621043.mp3 common_voice_sw_30682130.mp3 common_voice_sw_30682133.mp3 common_voice_sw_31255563.mp3 common_voice_sw_31255895.mp3 common_voice_sw_31450961.mp3 common_voice_sw_31465828.mp3 common_voice_sw_30574670.mp3 common_voice_sw_30574671.mp3 common_voice_sw_31389818.mp3 common_voice_sw_31444176.mp3 common_voice_sw_31192579.mp3 common_voice_sw_31192624.mp3 common_voice_sw_30580863.mp3 common_voice_sw_30580905.mp3 common_voice_sw_30627621.mp3 common_voice_sw_30627622.mp3 common_voice_sw_29381857.mp3 common_voice_sw_29382045.mp3 common_voice_sw_30562195.mp3 common_voice_sw_30562254.mp3 common_voice_sw_28246195.mp3 common_voice_sw_28246197.mp3 common_voice_sw_28246199.mp3 common_voice_sw_28246346.mp3 common_voice_sw_28246365.mp3 common_voice_sw_28246384.mp3 common_voice_sw_30711921.mp3 common_voice_sw_30711979.mp3 common_voice_sw_30712045.mp3 common_voice_sw_30659072.mp3 common_voice_sw_30659453.mp3 common_voice_sw_30659808.mp3 common_voice_sw_30621905.mp3 common_voice_sw_30622055.mp3 common_voice_sw_30622056.mp3 common_voice_sw_30666870.mp3 common_voice_sw_30667014.mp3 common_voice_sw_30667265.mp3 common_voice_sw_30630450.mp3 common_voice_sw_30642058.mp3 common_voice_sw_30644843.mp3 common_voice_sw_30586899.m ...
