# %%
print(plt.__version__)
# Out:
# 3.5.2

# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np

# %%
train = pd.read_csv('datasets/cv-corpus-8.0-2022-01-19/sw/train.tsv', sep='\t')
dev = pd.read_csv('datasets/cv-corpus-8.0-2022-01-19/sw/dev.tsv', sep='\t')
test = pd.read_csv('datasets/cv-corpus-8.0-2022-01-19/sw/test.tsv', sep='\t')
validated = pd.read_csv('datasets/cv-corpus-8.0-2022-01-19/sw/validated.tsv', sep='\t')
invalidated = pd.read_csv('datasets/cv-corpus-8.0-2022-01-19/sw/invalidated.tsv', sep='\t')
other = pd.read_csv('datasets/cv-corpus-8.0-2022-01-19/sw/other.tsv', sep='\t')
# Out:
# /home/ks/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print('train', len(train))
print('dev', len(dev))
print('test', len(test))
print('validated', len(validated))
print('invalidated', len(invalidated))
print('other', len(other))
# Out:
# train 19606
# dev 8805
# test 8941
# validated 99733
# invalidated 7756
# other 337702

# %%
labels = ['validated', 'train', 'dev', 'test']
# data = {'validated': len(validated),'train': len(train), 'dev': len(dev), 'test': len(test)}
clips = [len(validated), len(train), len(dev), len(test)]
sentences = [len(set(validated['sentence'])), len(set(train['sentence'])), len(set(dev['sentence'])), len(set(test['sentence']))]
# names = list(data.keys())
# values = list(data.values())

x = np.arange(len(labels))
width = 0.35

fig,axs = plt.subplots()

rect1 = axs.bar(x - width/2, clips, width, label='clips')
rect2 = axs.bar(x + width/2, sentences, width, label='sentences')
axs.bar_label(rect1, padding=3)
axs.bar_label(rect2, padding=3)
axs.set_xticks(x,labels)
axs.legend()
plt.ylim([0,110000])
# fig.suptitle('Categorical Plotting')
# fig.savefig('Training Data Metrics 4')

# %%
labels = ['train', 'dev', 'test']
# data = {'validated': len(validated),'train': len(train), 'dev': len(dev), 'test': len(test)}
clips = [ len(train), len(dev), len(test)]
# sentences = [len(set(validated['sentence'])), len(set(train['sentence'])), len(set(dev['sentence'])), len(set(test['sentence']))]
sentences = [len(set(train['sentence']))*2, len(set(dev['sentence']))*2, len(set(test['sentence']))*2]
# names = list(data.keys())
# values = list(data.values())

x = np.arange(len(labels))
width = 0.35

fig,axs = plt.subplots()

rect1 = axs.bar(x - width/2, clips, width, label='gold standard')
rect2 = axs.bar(x + width/2, sentences, width, label='silver standard')
axs.bar_label(rect1, padding=3)
axs.bar_label(rect2, padding=3)
axs.set_xticks(x,labels)
axs.legend()
plt.ylim([0,110000])
# fig.suptitle('Categorical Plotting')
fig.savefig('silver standard')

# %%
labels = ['train', 'dev', 'test']
# data = {'validated': len(validated),'train': len(train), 'dev': len(dev), 'test': len(test)}
clips = [ len(train), len(dev), len(test)]
# sentences = [len(set(validated['sentence'])), len(set(train['sentence'])), len(set(dev['sentence'])), len(set(test['sentence']))]
# sentences = [len(set(train['sentence']))*2, len(set(dev['sentence']))*2, len(set(test['sentence']))*2]
sentences = [len(set(train['sentence']))*3, len(set(dev['sentence']))*3, len(set(test['sentence']))*3]
# names = list(data.keys())
# values = list(data.values())

x = np.arange(len(labels))
width = 0.35

fig,axs = plt.subplots()

rect1 = axs.bar(x - width/2, clips, width, label='gold standard')
rect2 = axs.bar(x + width/2, sentences, width, label='bronze standard')
axs.bar_label(rect1, padding=3)
axs.bar_label(rect2, padding=3)
axs.set_xticks(x,labels)
axs.legend()
plt.ylim([0,110000])
# fig.suptitle('Categorical Plotting')
fig.savefig('bronze standard')

# %%
data = {'number of clips': len(validated['sentence'].append(invalidated['sentence']).append(other['sentence'])),'validated': len(validated), 'invalidated': len(invalidated), 'other': len(other)}
names = list(data.keys())
values = list(data.values())

fig,axs = plt.subplots()
rect = axs.bar(names, values)
axs.bar_label(rect, padding=3)
plt.ylim([0,500000])
# fig.suptitle('Categorical Plotting')
fig.savefig('Validation Metrics')

# %% [markdown]
# Number of Sentences

# %%
data = {'total number of sentences': len(set(validated['sentence'].append(invalidated['sentence']).append(other['sentence']))),
       'total number of clips': len(validated['sentence'].append(invalidated['sentence']).append(other['sentence']))
       }
names = list(data.keys())
values = list(data.values())

fig,axs = plt.subplots()
rect = axs.bar(names, values)
axs.bar_label(rect, padding=3)
# fig.suptitle('Categorical Plotting')
# str(list(data.values())[0])
# plt.ylim([0,500000])
# fig.savefig('Total Clips')

# %%
print('train', len(set(train['sentence'])))
print('dev', len(set(dev['sentence'])))
print('test', len(set(test['sentence'])))
print('validated', len(set(validated['sentence'])))
print('invalidated', len(set(invalidated['sentence'])))
print('other', len(set(other['sentence'])))
# Out:
# train 19606
# dev 8805
# test 8941
# validated 37352
# invalidated 7190
# other 39086

# %%
print('Total number of sentences')
print(len(set(validated['sentence'].append(invalidated['sentence']).append(other['sentence']))))
print(' ')
print('Total number of sentences included in the validated audios')
print(len(train['sentence'].append(dev['sentence']).append(test['sentence'])))
print(len(set(validated['sentence'])))
print(' ')
print('Total number of audios')
print(len(validated['sentence'].append(invalidated['sentence']).append(other['sentence'])))
print(' ')
print('Total number of validated audios, ie. those used in the train/dev/test split')
print(len(validated))
print(' ')
print('Total number of invalidated audios, these are excluded from the train/dev/test split')
print(len(invalidated))
print(' ')
print('Total number of yet to be validated audios, these are excluded from the train/dev/test split')
print(len(other))
# Out:
# Total number of sentences
# 39118
#
# Total number of sentences included in the validated audios
# 37352
# 37352
#
# Total number of audios
# 445191
#
# Total number of validated audios, ie. those used in the train/dev/test split
# 99733
#
# Total number of invalidated audios, these are excluded from the train/dev/test split
# 7756
#
# Total number of yet to be validated audios, these are excluded from the train/dev/test split
# 337702

# %% [markdown]
# Number of audios per sentence

# %%
validated['sentence']
# Out:
# 0                       Inajulikana kama shina la Warangi.
# 1                       Hasa aliandika riwaya na mashairi.
# 2        Wachaga hutania kwa kusema kuwa wapare wanakul...
# 3                 Alipenda kuimba na daima alitaka kuimba.
# 4        Watalii wanapenda sehemu hii kwa sababu hakuna...
#                                ...
# 99728                                    Aliitwa mara tatu
# 99729                                 Hana pesa za kutosha
# 99730                         Chakula chako si kitamu vile
# 99731                          Maradhi ya tumbo sio mchezo
# 99732          Nchi yetu haina mwelekeo dhabiti wa kisiasa
# Name: sentence, Length: 99733, dtype: object

# %%
Counter(list(validated['sentence'])).most_common()
# Out:
# [('Zote ziko ndani ya jimbo la Malindi.', 15),
#  ('Alikuwa mwanamke wa kwanza kuchaguliwa na kuongoza nchi ya Kiislamu.', 15),
#  ('Shule ya sekondari alimaliza vema katika masomo ya sayansi.', 15),
#  ('Alifanya hivyo ingawa alipenda zaidi maisha ya ndani ya monasteri.', 14),
#  ('Kadiri ya wanahistoria Wakristo.', 14),
#  ('Aliwahi kucheza timu ya taifa ya Romania.', 13),
#  ('Hall alianza kazi yake ya kamera kama mwigizaji wa kibiashara.', 13),
#  ('Anaishi mjini Heppenheim-Sonderbach, Hesse.', 13),
#  ('Uso wao ni mweusi.', 13),
#  ('Yeye huishi na hufanya mazoezi yake ya mbio Ngong,karibu na jiji la Nairobi.',
#   13),
#  ("Kufuatana na uainishaji wa lugha kwa ndani zaidi, Kibakati'-Sara iko katika kundi la Kiland-Dayak.",
#   13),
#  ('Njia za kuingiza dawa mwilini ni pamoja na mdomo, pua, ngozi au sindano.',
#   13),
#  ('Spishi zote za fuko-dhahabu zinatokea Afrika kusini kwa Sahara.', 12),
#  ('Anaheshimiwa na Kanisa Katoliki, Waorthodoksi, Waorthodoksi wa Mashariki, Walutheri na Waanglikana kama mtakatifu mfiadini.',
#   12),
#  ('Kwenye kiwango cha sifuri halisi hakuna mwendo wa maada au molekuli tena.',
#   12),
#  ('Isichanganywe na Kiwaray-Waray wa Ufilipino.', 12),
#  ('Hasa alichunguza mnururisho wa nyota.', 12),
#  ('Tofauti kati yao na Wayahudi wengine ilikuwa tu imani kuhusu Yesu.', 12),
#  ('Kihistoria watu wa China walikuwa wa kwanza wenye ujuzi wa kutengeneza hariri.',
#   12),
#  ('Ajira yake ilipatikana katika utawala wa bunge la senati ya Ufaransa.', 12),
#  ('Jina la lebo limetokana na nukta za kwanza za majina ya waanzilishi.', 12),
#  ('Mmenyuko kali ya mzio kawaida hutoa dalili mbalimbali zaidi ya dakika au masaa.',
#   12),
#  ('Miguu ya nyuma ina vidole vitano vyenye ngozi katikati.', 11),
#  ('Hakuna hospitali ya umma isipokuwa kliniki za binafsi.', 11),
#  ('Ameandika kwa "Lochaber Times".', 11),
#  ('Hatimaye aliuawa kwa ajili ya imani wakati wa dhuluma ya kaisari Decius.',
#   11),
#  ('Magharibi mwa Bahari ya Ross kipo Kisiwa cha Ross.', 11),
#  ('Wakazi asilia walikuwa Waindio.', 11),
#  ('Alicheza tena mechi yake ya pili dhidi ya Juventus katika klabu bingwa Ulaya.',
#   11),
#  ('Tangu kale anaheshimiwa na Wakatoliki na Waorthodoksi kama mtakatifu na babu wa Kanisa.',
#   11),
#  ('Ndege hawa wana mwili mwembamba, shingo ndefu, mkia mpana na domo lenye ncha kali.',
#   11),
#  ('Seoul ni kati ya miji muhimu ya biashara na uchumi kimataifa.', 11),
#  ('Said Ibn Al-`As.', 11),
#  ('Huenda anajulikana zaidi kwa jukumu lake katika Ufalme wa Ugaidi wa Mapinduzi ya Kifaransa.',
#   11),
#  ('Aliandika vitabu vya maisha ya kiroho.', 11),
#  ('Wakati huo, makao yao makuu yalikuwa mjini Elmhurst,katika eneo la Illinois.',
#   11),
#  ('Muda wa ofisi ya rais na makamu wa rais ni miaka minne.', 11),
#  ('Hasa aliandika tamthiliya.', 11),
#  ('Waziri huwa na jukumu la kutawala wizara, au idara Marekani.', 11),
#  ('Baada ya kufanywa abati wa monasteri huko Palestina.', 10),
#  ('Ni mji mkubwa wa nane katika nchi wa Uswidi.', 10),
#  ('Kwa nje Dunia ina gamba la mwamba mgumu.', 10),
#  ('Kabla ya uhuru yalitokea mabadiliko katika uongozi wa chama cha kikomunisti.',
#   10),
#  ('Hula majani ya manyasi, ya mimea na ya miti.', 10),
#  ('Siku hizi taa zote ni za umeme.', 10),
#  ('Jumla ya wakazi ni milioni sita na nusu.', 10),
#  ('Kila mtu huwa na mfumo wa kingamwili ndani yake.', 10),
#  ('Pamoja na kuruka alianza pia kuandika hadithi na masimulizi.', 10),
#  ('Kutoka hapa alirudi Moroko kupitia Makka.', 10),
#  ('Baada ya hapo, walianzisha kampuni ya kujenga ndege.', 10),
#  ('Wananchi walio wengi wanaishi nje: ni kama mara mbili kuliko waliobaki nchini.',
#   10),
#  ('Waliobaki wanaishi hasa Lebanoni, Israeli, lakini pia Venezuela, Marekani nakadhalika.',
#   10),
#  ('Alijaribu kuunganisha ufalme wake mkubwa kwa kujenga barabara nyingi.', 10),
#  ('Baada ya kupokea ubatizo alijitahidi sana kueneza Ukristo nchini.', 10),
#  ('Baada ya kufanya mtihani huu, yeye anaweza kujiunga na sekondari.', 10),
#  ('Alicheza mechi kuu wakati wa wakati wake na klabu hiyo.', 10),
#  ('Hakuna habari zaidi kuhusu malezi yake.', 10),
#  ('Anachezea klabu ya Polisi Tanzania nchini Tanzania.', 10),
#  ('Aliendelea kuandika juu ya maeneo mbalimbali kwenye masuala ya sayansi, teknolojia na maendeleo endelevu.',
#   10),
#  ('Lava wa jenasi tatu za visubi-kuvu huonyesha bio-uangazaji.', 10),
#  ('Kaskazini kawaida huwa juu zaidi kwenye ramani.', 10),
#  ('Bila ya shaka kwa upendo.', 10),
#  ('Pia ni balozi wa bidhaa mbalimbali.', 10),
#  ('Kinyume chake ni mzingo aktiki upande wa kaskazini ya Dunia.', 9),
#  ('Awe na maadili mema.', 9),
#  ('Akon alianza kuandika na kurekodi nyimbo katika studio yake ya nyumbani.',
#   9),
#  ('Uko katikati, upande wa magharibi.', 9),
#  ('Ilichukua muda sana hadi Ellen na mwenzake kurudi tena katika soko.', 9),
#  ('Sikukuu yake huadhimishwa kila mwaka tarehe ya kifo chake..', 9),
#  ('Kufuatana na uainishaji wa lugha kwa ndani zaidi, Kidijim-Bwilim iko katika kundi la Kiadamawa-Ubangi.',
#   9),
#  ('Prussia ilikuwa jimbo jamhuri ndani ya jamhuri la shirikisho la Dola ya Ujerumani.',
#   9),
#  ('Nambari ya ghorofa huhesabiwa kutumia mfumo wa kuhesabu ghorofa.', 9),
#  ('Mji mkuu wa New South Wales ni Sydney.', 9),
#  ('Kabla ya mafuriko, wana-elimu wa kale walifanya utafiti mkubwa sana katika eneo hili.',
#   9),
#  ('Aliyemfuata kama Tenno ni binamu yake Go-Nijo.', 9),
#  ('Mfano ni kikundi cha vijana waishio mitaani ambao wengi hawana kazi.', 9),
#  ('Amefanya kazi na wasanii wengi sana.', 9),
#  ('Kitabu hiki ni kuhusu ushirikiano wa tamaduni za magharibi na Afrika.', 9),
#  ('Imepakana na Kolombia, Peru na Bahari ya Pasifiki.', 9),
#  ('Kila picha pekee yake inaonyesha tu hali fulani bila mwendo.', 9),
#  ('Kata hii ipo mpakani kabisa mwa Uganda na ipo katikati ya msitu.', 9),
#  ('Nyumbani kwake ni bara la Afrika.', 9),
#  ('Uti wa mgongo wa Misri ya Kale ulikuwa mto Naili.', 9),
#  ('Hivyo ni kata kubwa zaidi katika Wilaya hiyo yote.', 9),
#  ('Katika hali hiyo, mtendaji mkuu huwa ni makamu wake.', 9),
#  ('Kutokana na uhaba hakuna matumizi mengi.', 9),
#  ('Imekuwa pia mila ya pekee kwenye Kisiwa cha Pemba, Tanzania.', 9),
#  ('Jimbo hili ni mojawapo ya Majimbo manne katika Kaunti ya Mombasa.', 9),
#  ('Kufuatana na uainishaji wa lugha kwa ndani zaidi, Kikaba-Deme iko katika kundi la Kibongo-Bagirmi.',
#   9),
#  ('Alihitimu elimu ya juu huko "University of Massachusetts-Amherst".', 9),
#  ('Katika hisabati umbali kazi au tani ni dhana ya umbali wa kimwili.', 9),
#  ('Matumizi mengine ni wakati wa kutoa mahubiri na mafundisho hata barabarani.',
#   9),
#  ('Alikuwa mtu wa Mungu na mtu wa maombi.', 9),
#  ('Mji mkuu ni Ngozi.', 9),
#  ('Aliuawa kwa ajili ya imani yake kwa kupigwa mawe.', 9),
#  ('Neno siguanaba au sihuanaba asili yake ni katika lugha za asili za Mesoamerica.',
#   9),
#  ('Kabla ya kufika kwa ukoloni kulikuwa na madola madogo mbalimbali', 9),
#  ('Inajulikana kama shina la Warangi.', 8),
#  ('Hawa ni hatari sana kwa sababu sumu yao ni kali sana.', 8),
#  ('Hoja wasiwasi kuhusu madhara kwenye uchumi wa Uingereza.', 8),
#  ('Kiko upande wa mashariki wa kisiwa cha Timor.', 8),
#  ('Kwa hivyo wana macho makubwa ili kuona vizuri kwa giza.', 8),
#  ('Elementi nyingine zinatokea pia kwa kiasi kidogo.', 8),
#  ('Illrymz kisha akaenda kwa miaka mitano kutoka kwa muziki.', 8),
#  ('Tangu kale anaheshimiwa na Waorthodoksi na Waorthodoksi wa Mashariki kama mtakatifu.',
#   8),
#  ('Kwa kawaida ugunduzi ni kazi tata.', 8),
#  ('Kwa mfano, Omugurudi wa ukoo wa mbwa wa Basimba totem ni Mauwe.', 8),
#  ('Kwa sababu hiyohiyo ni pia lugha rasmi mojawapo ya Umoja wa Ulaya.', 8),
#  ('Sikukuu yake huadhimishwa tarehe ya kifo chake.', 8),
#  ('Wapinzani walikamatwa na kufungwa.', 8),
#  ('Ugunduzi ulisababisha mafanikio makubwa katika utambuzi na kuboresha matibabu ya kupunguza makali ya virusi.',
#   8),
#  ('Namna ya C ni namna ya utaratibu kinyume cha lugha za programu nyingi.', 8),
#  ('Ina mamlaka ya kufanya maamuzi kwa niaba ya Shirikisho katika maeneo kadhaa.',
#   8),
#  ('Jimbo hili linapatikana katika Kaunti ya Marsabit, Mashariki mwa nchi.', 8),
#  ('Ni mji mkubwa wa saba katika nchi wa Korea Kusini.', 8),
#  ('Ndani yake ilikuwa na muundo wa shirikisho.', 8),
#  ('Yeye ndiye mwimbaji wa kike katika kikundi cha rap-rave Die Antwoord.', 8),
#  ('Pia, yeye ni mwanachama wa Sinema ya Kitaifa ya Uingereza.', 8),
#  ('Alifariki nchini Ujerumani.', 8),
#  ('Alipata sifa nyingi kama mtaalamu wa jiografia na mpelelezi.', 8),
#  ('Ni mji mkubwa wa kumi na mbili katika nchi wa Uswidi.', 8),
#  ('Shinikizo la juu la damu linatokana katika ushirikiano wa viini-urithi na athari za mazingira.',
#   8),
#  ('Iko kati ya Kuba upande wa magharibi na Puerto Rico upande wa mashariki.',
#   8),
#  ('Aliishi bila ya baba tangu ana miaka minne tu.', 8),
#  ('Ina jumba la makumbusho dogo kuhusu historia ya Zanzibar.', 8),
#  ('Unaweza kuingiza pia vipande vya nyama, samaki na karanga.', 8),
#  ('Beseni lake ni beseni kubwa le bara la Afrika.', 8),
#  ('Wakati huu alicheza misimu mitatu katika Ligi Kuu ya Uingereza.', 8),
#  ('Ni pia makao makuu ya Mkoa wa Njombe na Wilaya ya Njombe Vijijini.', 8),
#  ('Sehemu za mawingu hayo zinapatikana katika hali baridi kiasi chini ya sentigredi sifuri.',
#   8),
#  ('Kwa kawaida, ugonjwa huu ni sugu zaidi kwa watu wazima.', 8),
#  ('Mji mkubwa ni Johannesburg.', 8),
#  ('Pia alikuwa mkuu wa utawala wa kikoloni wa eneo hilo.', 8),
#  ('Iko kando ya Bahari ya Baltiki.', 8),
#  ('Ni asili ya Amerika ya kitropiki, ikiwa ni pamoja na Karibi.', 8),
#  ('Inajulikana sana kwa kuwa na ndege wengi na kwa mamalia wakubwa.', 8),
#  ('Mahakama pia inatoa mfumo wa kutatua migogoro.', 8),
#  ('Ndiyo tofauti kati ya misitu ya asili na isiyo ya asili.', 8),
#  ('Wengi wanaweza kuimba vizuri sana.', 8),
#  ('Viumbehai vidogo kama vile panzi-bahari ni malengo kwa viumbe vikubwa zaidi.',
#   8),
#  ('Iko katika kaskazini ya nchi kando la Bahari ya Baltiki.', 8),
#  ('Taarifa nyingine zinaeleza kuwa asili ya jamii ya Wakinga ni Afrika Kusini',
#   8),
#  ('Maiti kukataliwa na tumbusi na fisi wanaojulikana kama Ondili ama Olngojine',
#   8),
#  ('Pande nyingine ni pwani.', 7),
#  ('Mabadiliko haya yalikuwa ya kisiasa, kiuchumi na kijamii.', 7),
#  ('Lipo Kanisa Katoliki la Mt.', 7),
#  ('Kazi yake ya kufundisha alianza katika shule ya binafsi.', 7),
#  ('Kuhusu visiwa vingine mawazo hutofautiana.', 7),
#  ('Moyo pamoja na mishipa ya damu mwenye mwili huitwa mfumo wa mzunguko wa damu.',
#   7),
#  ('Alikuwa pia akifanya kazi katika kufanya maisha bora kwa watumwa wengine wa Dzungars.',
#   7),
#  ('Mbegu huwa kati ya vyakula muhimu sana kwa wanadamu.', 7),
#  ('Hoteli pia ina ukumbi mkubwa wa mkutano.', 7),
#  ('Amani mbinguni, na utukufu juu mbinguni!', 7),
#  ('Makao makuu yako katika Barabara ya Kiambu, Nairobi.', 7),
#  ('Walikuwa na njia nyingi kuunganisha alama hizi kwa kutaja maana za undani zaidi.',
#   7),
#  ('Hatimaye aliweza kuongea nae kuhusu bendi ya mtoto wake.', 7),
#  ('Watoto wanaweza kueneza virusi kwa zaidi ya mwaka.', 7),
#  ('Huko kuna uwezekano wa kuendesha feri bila injini kwa kutumia mwendo wa mto wenyewe.',
#   7),
#  ('Nge ina nyota nyingi zinazoonekana kwa macho ya kawaida.', 7),
#  ('Kaunti hupata misimu miwili ya mvua: Aprili hadi Juni na Oktoba hadi Disemba.',
#   7),
#  ('Ni mji upande wa kati ya nchi.', 7),
#  ('Alikuwa mrithi wa mali kubwa hivyo aliweza kuendesha maisha kufuatana na mapenzi yake tu.',
#   7),
#  ('Isichanganywe na Kisenoufo-Syenara nchini Mali ambayo ni lugha tofauti.',
#   7),
#  ('Mwili wa tunda unaweza kuwa na rangi ya njano, ya dhahabu, au ya machungwa.',
#   7),
#  ('Wana domo pana pia lakini shingo yao ni fupi zaidi.', 7),
#  ('Baada ya tangazo hili Nelson Mandela alikubali kuondoka gerezani.', 7),
#  ('Mchezaji wa mguu ya kulia, mara nyingi anacheza kama kiungo wa kati.', 7),
#  ('Kuna vijiji vingi vya wavuvi kwenye mwambao.', 7),
#  ('Alirudi Tanganyika, ambapo aliteuliwa na waziri mkuu Nyerere kuwa mbunge katika Bunge la Tanganyika.',
#   7),
#  ('Wachezaji bora ulimwenguni hucheza kwenye timu hizi.', 7),
#  ('Chakula chao ni sehemu za mimea ya maji, haswa mbegu na majani.', 7),
#  ('Yeye hufanya ripoti nyingi juu ya hali katika eneo hili.', 7),
#  ('Humo alieleza masharti ya utawala kwa kiongozi wa kisiasa.', 7),
#  ('Hii ilikuwa ishara ya utakatifu.', 7),
#  ('Los Angeles, hasa eneo la Hollywood, ni kitovu cha kupiga picha za filamu.',
#   7),
#  ('Sikukuu yake huadhimishwa tarehe ya kifo chake au Jumamosi ya kwanza ya Novemba.',
#   7),
#  ('Ilipata viwango vya juu vya watazamaji huko Korea Kusini na umaarufu kote Asia.',
#   7),
#  ('Williams anaishi Texas akiwa na mkewe pamoja na binti yao.', 7),
#  ('Wikipedia hii ilianzishwa mnamo tarehe moja mwezi wa pili', 7),
#  ('Ndege huyu huonekana katika nembo ya nchi za Sudan na Afrika Kusini.', 7),
#  ('Tangu kale wanaheshimiwa na Wakatoliki na Waorthodoksi kati ya watakatifu wafiadini.',
#   7),
#  ('Kwa kuwa hayajulikani mengine kuhusu historia yao, haorodheshwi tena na Martyrologium Romanum.',
#   7),
#  ('Tunda lina ngozi gumu kiasi yenye rangi ya kijani.', 7),
#  ('Iko kaskazini magharibi mwa nchi.', 7),
#  ('Sikukuu yake inaadhimishwa katika tarehe ya kifo chake.', 7),
#  ('Wakati huohuo aliandika pia masimulizi na vitabu.', 7),
#  ('Pia alitunga hotuba mia kadhaa na vitabu sita.', 7),
#  ('Dar es Salaam inakadiriwa kuwa na wakazi wapatao milioni tatu.', 7),
#  ('Ncha ya kusini ya kijiografia iko katikati ya bara la Antaktiki.', 7),
#  ('Mbegu nyeusi ni kubwa kiasi.', 7),
#  ('Badala ya dawa ya meno vinaweza kutumika chumvi na magadi.', 7),
#  ('Kwa sababu hiyo inaitwa pia "Sala ya Bwana".', 7),
#  ('Huyu ndiye Mwafrika-Mwamerika wa kwanza kuwa Mwanamke wa Kwanza wa Marekani.',
#   7),
#  ('Mara nyingi huwa na harufu nzuri na inaweza kutumika kama kiungo.', 7),
#  ('Asali hujenga afya.', 7),
#  ('Pia, Guthrie alichunguza lugha ya nasaba ambayo ni chanzo cha lugha zote za Kibantu.',
#   7),
#  ('Wako pia Uganda na Tanzania.', 7),
#  ('Wakatoliki walikuwa pia na shule ya ufundi.', 7),
#  ('Aliolewa na Bernow, Lindström, Ziems, na Renat.', 7),
#  ('Kulingana na mbinu za mpangilio, muundo fulani, kwa mfano.', 7),
#  ('Ameandika makala mbalimbali za kisiasa, utamaduni na mambo ya kijinsia.',
#   7),
#  ('Wimbo una mandhari mengi ya kutumika katika harusi.', 7),
#  ('ya nchini Hispania.', 7),
#  ('Mwanachama mwandamizi wa kila moja ya mgawanyiko huu mpya alikua kichwa cha Muwuluko.',
#   7),
#  ('Anaingia mwaka wa kumi katika msimu huu akiwa katika ubora ule ule Simba',
#   7),
#  ('Mwaka elfu mbili na tano Kitulo likatangazwa kuwa hifadhi ya Taifa', 7),
#  ('Jina hili Ziwa Magharibi lilidumu katika kipindi cha ukoloni', 7),
#  ('Kuna sababu mbalimbali za kuelezea umaarufu wa bahari hii.', 7),
#  ('Mikoa mingine itakuwa na miundombinu ya maji ya dhoruba inayofaa zaidi', 7),
#  ('Wanawake huimba nyimbo tulivu na nyimbo za kuwasifu watoto wao', 7),
#  ('Moshi ni maeneo ya mwanzo ambayo wamisionari wa Ukristo walijenga makanisa na shule',
#   7),
#  ('Ni moja ya kabila ambalo lugha yake ina utajiri wa maneno', 7),
#  ('Mac-Auley alihitimu na shahada ya Kiingereza katika Delta State university.',
#   6),
#  ('Ni mtoto wa Julius Nyerere, rais wa kwanza wa Tanzania na "baba wa Taifa".',
#   6),
#  ('Kisayansi ni mmenyuko wa kikemia kati ya oksijeni ya hewani na kampaundi za kaboni.',
#   6),
#  ('Tauni ilifika Ulaya kwa njia ya meli za biashara kutoka Asia.', 6),
#  ('Maeneo ya mpaka wa Tanzania kuna pia wasemaji kadhaa huko Malawi na Zambia.',
#   6),
#  ('Wakati wa kujifunza lugha alianza tayari kukusanya hadithi na masimulizi ya Wachagga.',
#   6),
#  ('Jina Bakari linatokana na ar.', 6),
#  ('Tangu zamani ni wakulima, na kwa sasa wengi ni Wakristo.', 6),
#  ('Kulingana na kemia ya kisasa ni ujenzi wa mata kwa kiwango cha atomi.', 6),
#  ('Walikuwa wafanyabiashara na mabaharia hodari sana.', 6),
#  ('Muda si mrefu baada ya kifo chake alianza kuheshimiwa kuwa mtakatifu.', 6),
#  ('Nafaka kama ngano nyekundu na shayiri huleta pia mkate mweusi zaidi.', 6),
#  ('Hasa alichunguza vipengele mbalimbali vya chembe hai.', 6),
#  ('Shule hii iko nje ya jiji la Nairobi, Kenya.', 6),
#  ('Yaani wana ladha mbaya.', 6),
#  ('Anachezea timu ya taifa ya Uthai.', 6),
#  ('Ni sawa kabisa kusema ya kwamba reli hii ilikuwa mwanzo na mbegu wa Kenya.',
#   6),
#  ('Albamu ilitolewa mnamo tarehe moja mwezi wa pili', 6),
#  ('Hao ni nani?', 6),
#  ('Bei si kubwa sana.', 6),
#  ('Milipuko inaweza kutokea sambamba na tetemeko la ardhi.', 6),
#  ('Lakini ukuu wa Isaya uko hasa upande wa imani.', 6),
#  ('Babake Hans alikuwa mchoraji pia lakini hakuna habari zaidi juu yake.', 6),
#  ('Anaheshimiwa na baadhi ya Wakristo kama mtakatifu.', 6),
#  ('Ni hivyo katika Makanisa ya mashariki na ya magharibi vilevile.', 6),
#  ('Mto huo unaishia kwenye mto Imo.', 6),
#  ('Wana rangi mbalimbali kama kahawia, nyeupe na nyeusi kadiri ya spishi.', 6),
#  ('Pamoja vyumba viwili vya sheria hufanya mwili maamuzi nchini Nigeria kinachoitwa Bunge.',
#   6),
#  ('Waliuawa kwa ajili ya imani ya Kikristo wakati wa dhuluma ya kaisari Diokletian.',
#   6),
#  ('Hata hivyo, kuna dalili chache au hakuna kabisa kwa ujumla.', 6),
#  ('Hivyo mabamba ya gandunia yana mwendo wakati wote.', 6),
#  ('Katika muda mfupi alifaulu kuunganisha makabila ya Algeria ya magharibi chini ya uongozi wake.',
#   6),
#  ('Mawingu ni mahali ambako mvua na theluji hutoka.', 6),
#  ('Tangu kale anaheshimiwa na Wakristo wa madhehebu mengi kama mtakatifu.', 6),
#  ('Bahari ya Kaskazini iko upande wa magharibi, Baltiki inaanza kwenye visiwa vikuu vya Denmark.',
#   6),
#  ('Mara nyingi huwa la ngozi, lakini yale ya kisasa hufanywa kutoka kwa vifaa mbalimbali.',
#   6),
#  ('Unapatikana katika kitongoji cha Mouassine.', 6),
#  ('Ndiye mwakilishi wa bunge kwa ujumla.', 6),
#  ('Kiasili inapatikana katika kampaundi mbalimbali.', 6),
#  ('Iko katika Mashariki ya nchi.', 6),
#  ('Ilikuwa kituo cha posta na pia cha kikosi na.', 6),
#  ('Kufuatana na uainishaji wa lugha kwa ndani zaidi, Kibali iko katika kundi la Kibali-Sasak-Sumbawa.',
#   6),
#  ('Matumizi ya lugha ni njia ya kuweka na kuonyesha utambulisho wa kikundi fulani.',
#   6),
#  ('tumaini pekee kwa wamarekani sasa ni chanjo.', 6),
#  ('Kuna nchi moja tu ndogo zaidi ambayo ni mji wa Vatikano.', 6),
#  ('Gabon ni nchi yenye neema sana kuliko nchi jirani.', 6),
#  ('Idadi ya wasemaji nchini Mali haijulikani.', 6),
#  ('Utukufu una yeye milele.', 6),
#  ('Pengine linamaanisha viumbe vingine, kama vile malaika.', 6),
#  ('Shughuli kuu za wakazi wake ni kilimo, ufugaji, biashara, uzalishaji wa chumvi na uvuvi.',
#   6),
#  ('Hivi karibuni, amekuwa akifanya kazi uchumi wa kisiasa wa mageuzi ya kiuchumi nchini Tanzania.',
#   6),
#  ('Pamoja na Kigoma inafanya manisipaa ya Kigoma-Ujiji.', 6),
#  ('Hakuna wasemaji ambao wamebaki kuongea Kigabi-Gabi, yaani lugha imetoweka kabisa.',
#   6),
#  ('Kufuatana na uainishaji wa lugha kwa ndani zaidi, Kigabi-Gabi kiko katika kundi la Kiwaka-Kabiki.',
#   6),
#  ('Video yake ilitolewa mnamo tarehe moja mwezi wa pili', 6),
#  ('Baadhi ni ngumu, kama almasi.', 6),
#  ('Kwa kawaida huitwa "ziwa", si "hori".', 6),
#  ('Dola lilikuwa na katiba, serikali na bunge.', 6),
#  ('Pia, ni wimbo pekee kutoka katika albamu kuwa na muziki wa video.', 6),
#  ('Mifano ya rasi kubwa ni nchi za Italia na Korea au Bara Hindi.', 6),
#  ('Tabia kuu ya kufanana na sayari ni umbo la tufe.', 6),
#  ('Pia wanatajwa kama chakula maalumu cha Yohane Mbatizaji, mtangulizi wa Yesu.',
#   6),
#  ('Huu ndiyo mji mkubwa kabisa katika jimbo hili.', 6),
#  ('Kijiji hiki kina jumla ya shule za msingi mbili.', 6),
#  ('Wanatokea katika maji au mahali pa majimaji.', 6),
#  ('Uhusiano kati ya madhehebu ya Kikristo ulikuwa mbaya kwa muda mrefu.', 6),
#  ('Njia hii inaweza kutunza kumbukumbu ya kudumu.', 6),
#  ('Ni mto mkubwa wa maji meusi duniani.', 6),
#  ('Vilevile tangu kale watu waliwahi kupanga nyota za angani katika kundinyota.',
#   6),
#  ('Mifano ni chuo cha ufundi, chuo cha kilimo au chuo cha ualimu.', 6),
#  ('Na hata katika Afrika spishi kadhaa zinatokea maji baridi hasa.', 6),
#  ('Inasemekana pia alikuwa mfuasi wa Augustino wa Hippo.', 6),
#  ('Wazaramo ambao kiasili watani zao ni wanyamwezi', 6),
#  ('Sehemu ya mashariki iko chini ya Marekani.', 6),
#  ('Busia iko kwenye mpaka na Kenya.', 6),
#  ('IoT pia inaweza kutumika katika mifumo ya huduma ya afya.', 6),
#  ('Mifano ni kimbi-a, kimbi-lia, kimbili-ana, kimbi-za, kimbi-zana, kimbi-liwa.',
#   6),
#  ('Yeye alikuwa na kaka na dada ishirini na nne.', 6),
#  ('Wala yeye mwenyewe asingejitenga siku hizi kama alivyofanya', 6),
#  ('Kwa hiyo ni sehemu ya mmea iliyopo juu ya ardhi.', 6),
#  ('Tabia ya hali hii ni tofauti na hali ya gesi yenyewe.', 6),
#  ('Wakristo karibu wote ni wa asili ya Ulaya.', 6),
#  ('Msingi wa filamu ni mbinu wa kushika mwendo fulani kwa picha nyingi.', 6),
#  ('ili kudai eneo lao.', 6),
#  ('Leo ni Jumamosi".', 6),
#  ('Sikukuu yao huadhimishwa siku ya kifodini chao.', 6),
#  ('Chanzo cha Madrid ni katika zamani za Waroma katika Hispania.', 6),
#  ('Wilaya ipo kusini magharibi mwa Mkoa wa Lindi.', 6),
#  ('Waliuawa kwa upanga pamoja na Patriarki Petro I wa Aleksandria.', 6),
#  ('Dola miji ilikuwa muhimu sana katika nchi nyingi kihistoria.', 6),
#  ('Ndipo watu hao walipoanza kupata jina moja lililowatambulisha kwa wageni',
#   6),
#  ('Pia amecheza kwenye timu ya taifa ya Uingereza.', 6),
#  ('Neno la Kimasai kwa tohara ni emorata', 6),
#  ('Tokeo mojawapo la vita kuu ya pili ni kuanzishwa kwa Umoja wa Mataifa.', 6),
#  ('Mwelekeo wake ni ncha ya kusini ya dunia.', 6),
#  ('Timu zinaweza kubadilisha idadi yoyote ya wachezaji wao kati ya uchezaji.',
#   6),
#  ('Chifu Mwene Ngalu alikuwa mtu mwenye upendo na hakupenda uchafu wa aina yoyote',
#   6),
#  ('Wazee wa Kimaasai hukutana na kuamua kwamba wavulana wao wako tayari kutahiriwa',
#   6),
#  ('Walipokaa kwenye pwani walikuwa karibu na makazi ya Waswahili', 6),
#  ('Wachaga hutania kwa kusema kuwa wapare wanakula ugali kwa picha ya samaki',
#   5),
#  ('Alipata upasuaji ambao uliondoa sehemu ya moyo iliyoharibika', 5),
#  ('Mkoani Kagera mpakani mwa Tanzania na Rwanda', 5),
#  ('Anachezea timu ya taifa ya Kenya.', 5),
#  ('Lionel Messi Mchezaji wa pili bora duniani baada ya McGregor ni mshambuliaji wa Barcelona',
#   5),
#  ('Hiki ni kiini cha uchawi wa kazi', 5),
#  ('ni chuo kikubwa cha masomo kwa njia ya barua.', 5),
#  ('Asili ya farasi wote ni aina za farasi mwitu wa porini.', 5),
#  ('Mara nyingi ugonjwa huwa hauonyeshi dalili kwa muda mrefu', 5),
#  ('Hali ya Kitropikali wilaya Ngorongoro ina mvua za wastani', 5),
#  ('hifadhi ya mahale ni makazi ya sokwe kama ilivyo gombe', 5),
#  ('Kabla ya kugonga mwamba huo nahodha na waongoza meli hiyo walipata maonyo sita',
#   5),
#  ('Staili kama ya Mourinho ilipigiwa kelele', 5),
#  ('Hadi elfu moja mia tisa sabini na tano', 5),
#  ('Ugumu ambao sisi sote tunapitia maishani', 5),
#  ('Usafi hufanyika kwa kuoga na kusafisha mazingira yanayokuzunguka', 5),
#  ('Elimu ya Kirumi ya vijana wasomi wa Kirumi haikujumuisha Uvuvi', 5),
#  ('Mara nyingi matibabu ni magumu.', 5),
#  ("Kifupi chake rasmi kufuatana na Ukia ni 'Com'.", 5),
#  ('Kisii ndio makao makuu ya Kaunti ya Kisii.', 5),
#  ('Nchini Ujerumani "senati" ni jina la vitengo vya mahakama kuu.', 5),
#  ('Historia ya muziki saa Starehe ni mkono na marafiki wa Starehe pamoja.', 5),
#  ('Timor ya Mashariki ni kati ya nchi maskini zaidi duniani.', 5),
#  ('Alianzisha mfumo wa vyama vingi na kufungua uchumi kwa makampuni ya binafsi.',
#   5),
#  ('Wakati ambapo ilikuwa bado ni kama marufuku kuzungumza wazi wazi', 5),
#  ('Ndani ya mji wa Tanga athari za wageni bado zimo nyingi tu', 5),
#  ('mpira wa uingereza ulikuwa wa pasi tatu kisha goli', 5),
#  ('wale wenye mamlaka ya kuleta matokeo chanya katika kuboresha hali ya usafiri majini',
#   5),
#  ('Kiongozi huyo mwenye utata alisifiwa na wafuasi wake kama kiongozi wa ujamaa',
#   5),
#  ('Suetonius anakumbuka jinsi Wafalme Tiberius na Gayo', 5),
#  ('Alidhani mawazo yake hayo si mapya bali kwamba ndiyo mafundisho ya mtume',
#   5),
#  ('Lengo la msingi la mwanafunzi ni kwa ujumla kutokana na uzoefu wake.', 5),
#  ('Ilitengenezwa pia katika China na Mashariki ya Kati.', 5),
#  ('Hadi leo asili ya maneno kutoka Kijerumani na Kifaransa ni wazi kabisa.',
#   5),
#  ('Mwili wa binadamu huwa na seli milioni kadhaa, na nyingi zina viini vya seli.',
#   5),
#  ('Taratibu za hali ya hewa ya huko ni theluji, baridi, na kiangazi cha wastani.',
#   5),
#  ('Alipaka rangi usiku baada ya kazi.', 5),
#  ('Kaskazini kuna tambarare kubwa lenye rutuba.', 5),
#  ('Rangi yao ni kijivu au kahawia juu na nyeupe chini.', 5),
#  ('Kiholanzi ni lugha ya Kigermanik ya magharibi katika jamii ya lugha za Kihindi-Kiulaya.',
#   5),
#  ('Eneo aliwahi kuwa kuongezeka kwa sinema kadhaa.', 5),
#  ('Asidi amino zote zina ncha tofauti za ki-isoelektriki.', 5),
#  ('Pia kuna wasemaji wachache nchini Sudan Kusini.', 5),
#  ('Pia, yeye ana mwana anayeitwa Hussein.', 5),
#  ('Mazungumzo yalikuwa magumu sana.', 5),
#  ('Ni pana zaidi ya mamalia yoyote ya mwitu katika nchi za Magharibi.', 5),
#  ('Arndt watoto wawili wa kiume na mmoja wa kike.', 5),
#  ('miguu ya kusimama kutambulika na kuungwa mkono na madola yenye kupenda', 5),
#  ('kuna baadhi ya nchi imegawanywa ndani ya nchi zao', 5),
#  ('Baada ya utekelezaji wa vikwazo vya Umoja wa Mataifa dhidi ya serikali ya Rhodesian',
#   5),
#  ('Hasa baada ya kutembelea eneo lenye mlipuko', 5),
#  ('Mtaa wa nne Kange nako palinivutia nijue maana yake lakini sikufanikiwa',
#   5),
#  ('Siku hizi watoto wa Kimasai wanakwenda shule wanalima na wameendelea kiuchumi',
#   5),
#  ('waathirika walisema waliwekwa kizuizini kwa wiki kadhaa pasipo mawasiliano',
#   5),
#  ('Al Zawahir ambaye alimwambia kuwa yuko karibu na Osama', 5),
#  ('mzee mwinyi anastahili sifa kubwa kwa kazi yake', 5),
#  ('Kikuu cha Kimataifa cha Mabasi cha Dar es Salaam', 5),
#  ('Pia uwepo wa bahari hii unasaidia sana watu kupata viburudisho mbalimbali',
#   5),
#  ('Mwanasheria maarufu jina lake Zeno aliishi karibu na Anthemius katika Byzantium',
#   5),
#  ('Husemekana kuwa wanatengeneza rika Jipya Olaiguenani na Olopolosi', 5),
#  ('Jiji lina eneo la ukubwa wa kilomita za mraba mia sita', 5),
#  ('Miundombinu kama vile barabara imerahisisha gharama za usafiri', 5),
#  ('Bawasiri hii hutokea katika eneo la mwisho kabisa la mfereji wa haja kubwa',
#   5),
#  ('Katika soka la kisasa huwa kuna mabadiliko madogo hii imesababisha baadhi ya wachambuzi',
#   5),
#  ('Unaweza kwenda kutembelea hifadhi hii kwa ndege za abiria au za kukodi', 5),
#  ('pacha wa bobby moore naye alitajwa kwenye orodha ya nyota bora duniani', 5),
#  ('Mwamuyinga anasema Mwamubambe alimvamia Mhalwike kichakani', 5),
#  ('Ukitokea Iringa iko kabla ya kufikia Tanangozi', 5),
#  ('lenye maana ya Kiwara kisichoisha kwa lugha hiyo ya kimasai ndipo kukaitwa serengeti',
#   5),
#  ('Wanatumia Liemba kama njia ya usafiri wa uhakika kwenye ziwa hili', 5),
#  ('karibu na jengo la Mwene Ngalu ambalo hivi sasa limebaki gofu tu', 5),
#  ('Asili ya miji ya Waswahili inapatikana katika biashara hiyo', 5),
#  ('Alifanya mahusiano na wakala wa Uingereza na Israeli nchini', 5),
#  ('Mkwawa au kwa jina refu Mkwavinyika Munyigumba Mwamuyinga', 5),
#  ('Pastory bushozi alikuwa miongoni mwa watafiti wa zana za mawe', 5),
#  ('Sehemu ya vikosi vya Jeshi la Uganda viliripotiwa kumhimiza Amin aondoke madarakani',
#   5),
#  ('uwepo wa guardiola umebadilisha staili ya mpira', 5),
#  ('Vivutio hivi ni utajiri mkubwa wa', 5),
#  ('Wengi sana zaidi walidhulumiwa.', 5),
#  ('Anakumbukwa kwa sababu aliweka misingi ya mbinu mpya za sayansi zinazoendelea kutumika hadi leo.',
#   5),
#  ('Alikuwa wa kwanza kueleza jinsi ya kuenea kwa homa ya madoa madoa.', 5),
#  ('Upo kwenye pwani ya Bahari Nyeusi.', 5),
#  ('Jina la nchi linatokana na lile la mji mkuu, Jibuti.', 5),
#  ('Na ni kawaida kuandika kuhusu watu maarufu.', 5),
#  ('Tangu kale anaheshimiwa na Wakatoliki na Waorthodoksi kama mtakatifu pamoja na familia yake yote.',
#   5),
#  ('Katika nyakati tofauti katika kipindi hiki, yeye ilikuwa iko katika pande zote za mpaka.',
#   5),
#  ('Bungo-mavi ni imara wenye mabawa magumu sana ya mbele.', 5),
#  ('Anasema, "Mariah ni maarufu kimataifa.', 5),
#  ('Wengi wao huongea hasa Krioli ya Kiingereza, ingawa Kiholanzi ndicho lugha rasmi.',
#   5),
#  ('Wanaweza kusikia sauti kwa umbali wa kilomita kadhaa.', 5),
#  ('Musoma imepata halmashauri na hadhi ya manisipaa.', 5),
#  ('Kwa kifupi tu Njozi ni tukio lolote la ndoto inaweza kuwa nzuri au mbaya',
#   5),
#  ('Wizara ya elimu na Utamaduni.', 5),
#  ('Alikuwa kiongozi wa kwanza wa jumuia ya kike wa utawa huo.', 5),
#  ('Chaji hizi mbili ni kinyume zinaitwa chaji hasi na chaji chanya.', 5),
#  ('ndoa za kabila tofauti.', 5),
#  ('Ufaransa iliendelea kumsaidia.', 5),
#  ('Mkwawa alizaliwa mahali palipoitwa Luhota karibu na Iringa mjini', 5),
#  ('Harara mwilini au kuumwa na koo katika wiki chache za kwanza', 5),
#  ('Mara moja serikali ilianza kulazimisha mfumo wa chama kimoja cha kisiasa',
#   5),
#  ('Huruma ya ajabu kuliko zote!', 5),
#  ('Zaidi ya nusu ya eneo ni maji.', 5),
#  ('Aliteuliwa kuwa askofu wa Hamburg, upande wa kaskazini wa Ujerumani.', 5),
#  ('Hata hivyo, sasa anacheza Hispania.', 5),
#  ('Katika Asia ikweta inapita funguvisiwa ya Indonesia.', 5),
#  ('Uteuzi wa Tuzo ya Chaguo.', 5),
#  ('Kuna kisiwa kikubwa cha Madagaska na funguvisiwa mbalimbali.', 5),
#  ('Alizaliwa katika familia tajiri.', 5),
#  ('Hutengenezwa pia katika maabara.', 5),
#  ('Mji wa Chicago ni mji mkubwa sana katika Marekani, lakini haikuwa hivyo wakati wote.',
#   5),
#  ('Sikukuu yake huadhimishwa tarehe yake ya kuzaliwa au ya kuuawa.', 5),
#  ('Kijadi Wamasai hula nyama na maziwa pia damu ya ngombe', 5),
#  ('Lipo chini ya bahari ya Pasifiki ikiwa ni bamba la gandunia kubwa kabisa.',
#   5),
#  ('Huduma ya simu inapatikana.', 5),
#  ('Kwa hivyo wanaweza kukamatwa bila shida.', 5),
#  ('Riwaya zake ni juu ya mauaji na ugunduzi wake.', 5),
#  ('Kwa asili alikuwa Mjerumani lakini alifanya kazi hasa katika Milki ya Osmani.',
#   5),
#  ('Iko katika mkoa wa Moscow Oblast.', 5),
#  ("Ng'ambo ya bahari iko Uchina upande wa magharibi na Japani upande wa kusini-mashariki.",
#   5),
#  ('Karibu nusu ya wakazi wote wa Mongolia wanaishi hapa.', 5),
#  ('Iko kati ya kidole kikubwa na kidole cha mwisho.', 5),
#  ('Tangu kale anaheshimiwa na Wakatoliki na Waorthodoksi kama mtakatifu pamoja na mumewe.',
#   5),
#  ('Hawana muda mwingi kwa mahitaji ya wengine.', 5),
#  ('Tangu kale anaheshimiwa na Kanisa Katoliki, Waorthodoksi na Waorthodoksi wa Mashariki kama mtakatifu mfiadini.',
#   5),
#  ('Ndilo la asili la nyanda za juu za kati nchini.', 5),
#  ('Hata lugha za Ethiopia hufuata mtindo wa kufanana nayo.', 5),
#  ('maumivu wakati wa kushiriki ngono ni ya kawaida.', 5),
#  ('Tume ya uchaguzi ilitangaza matokeo ya kuwa', 5),
#  ('Desturi hiyo ni ya kale, labda kama ujenzi wenyewe wa makanisa.', 5),
#  ('Kwa jumla watu walifanya kazi kwa kushirikiana bila ubaguzi wala matabaka.',
#   5),
#  ('Pia kuna chanjo dhidi yake.', 5),
#  ('Hata hivyo watu wa Liberia huongea Kiingereza sana.', 5),
#  ('Husafiri kutoka milima ya kaskazini kuelekea nyanda za kusini', 5),
#  ('Tangu kale wanaheshimiwa kama watakatifu wafiadini.', 5),
#  ('Saturninus alifuata na kushika msimamo katika kuteswa.', 5),
#  ('Tangu kale anaheshimiwa na Kanisa Katoliki, Waorthodoksi na Waorthodoksi wa Mashariki kama mtakatifu.',
#   5),
#  ('Aliendelea kuchora picha nyingi za dini juu ya habari na watu wa Biblia.',
#   5),
#  ('Wimbo wake ni kati ya maandiko matakatifu ya kale zaidi.', 5),
#  ('Kwa ghasia yake wakati wa vita.', 5),
#  ('Katika nchi nyingi huwa na kawaida ya kutembelea pia makaburi ya marehemu.',
#   5),
#  ('Alifariki huko akiwa mzee sana.', 5),
#  ('Katika moja ya safari hizi, alisaidia sana kuongoza chombo kwa usalama.',
#   5),
#  ('Nchi yetu haina mwelekeo dhabiti wa kisiasa', 5),
#  ('mechi zote mbili mbinu za guardiola hazikuzaa matunda', 5),
#  ('Serikali ya Yoweri Museveni ilirudisha falme za kale kama enzi za kiutamaduni',
#   5),
#  ('Huyu Sultani ndiye was mwisho Jemshid bin abdalla', 5),
#  ('Vifaa vilivyotumika katika kujengea Chuo hicho ni mawe na chokaa iliyochomwa',
#   5),
#  ('Ni samaki wa aina ya sangara sato kamongo migebuka na kuhe', 5),
#  ('Tozo hizi zimeondolewa ili kuwawezesha wafanyabiashara kufanya biashara zao hapa nchini',
#   5),
#  ('Akaendelea kufundisha na akapelekewa barua iliyomtishia kumtenga na Kanisa',
#   5),
#  ('Suala la fedha limekuwa mtihani na kikwazo kikubwa cha kunasa saini yake',
#   5),
#  ('Kwa kawaida wachezaji wanaocheza katika nafasi moja hucheza katika mstari ulionyooka',
#   5),
#  ('timu kubwa zina historia kubwa sana', 5),
#  ('Wafanyakazi wa vyombo vya habari ambao wana utaalam katika sanaa ya uchambuzi',
#   5),
#  ('Mkutano huu pia ukaazimia kuwa na wawakilishi katika sekta ndogo za utalii',
#   5),
#  ('Karibu miji na vijiji vyote viko kwenye pwani la kaskazini.', 5),
#  ('Hali hiyo inaweza kutokea kiasili katika mazingira maalumu au kwa kutumia mbinu fulani.',
#   5),
#  ('Vita Kuu ilianza kutokana na ugomvi kati ya Austria-Hungaria na Serbia.',
#   5),
#  ('Anaheshimiwa kama mtakatifu na Kanisa Katoliki, Waorthodoksi, Waanglikana, Walutheri na madhehebu mengine ya Ukristo.',
#   5),
#  ('Hivyo kamusi hizo hutajwa kama "Madan-Johnson".', 5),
#  ('Hakikisha unapiga mswaki walau mara mbili kwa siku kila siku baada ya kula',
#   5),
#  ('Mpandaji anafika juu ya kimo cha mstari wa jeledi', 5),
#  ('misri waliitumia sudan kama kituo cha kuhifadhi watumwa', 5),
#  ('Baada ya Messi kupachika wavuni goli lake la kwanza', 5),
#  ('kipindi cha korosho kinapofika wananchi wa mtwara wanafurahia', 5),
#  ('pep anashinda makombe na anaburudisha wapenzi wa soka', 5),
#  ('Waliendelea na safari pamoja na ngombe wao mpaka mkoani Singida', 5),
#  ('Tanzania imeweka rekodi ya aina yake juu ya vivutio vyake vyote vitatu', 5),
#  ('Na huleta mvua ya milimita mia moja kwa wastani kwa mujibu wa sensa', 5),
#  ('Shangwe hiyo ikifanywa na wanaume pekee huitwa engoliga', 5),
#  ('Maandishi mbalimbali ulimwenguni yaliandikwa wakati wa utawala wake', 5),
#  ('Lipatikana kama Wanyaturu wanaovyoamini hutokana na bahati', 5),
#  ('Miaka ya elfu moja mia tisa sabini na elfu moja mia tisa themanini', 5),
#  ('mfugale ametumia muda wake mwingi kufanya kazi kama mtaalamu wa madaraja',
#   5),
#  ('kwa kuwa watoto wote hupaswa kwenda shule', 5),
#  ('Kuzungumza na Mungu na unabii kuhakikisha mafanikio katika vita', 5),
#  ('Kwa upande wa mbio za magari Kenya ndio waandalizi wa mbio za magari', 5),
#  ('Wavulana kutoka kaskazini hufanya mashindano ya kunyanganyana pembe ya ngombe',
#   5),
#  ('kina cha ziwa ni ni meta mia saba hamsini', 5),
#  ('Njia hizi mbili za kitamaduni zinafanywa kwa kupokezana', 5),
#  ('baadhi ya watu hukata tamaa ya maisha kabisa', 5),
#  ('soka la pasi nyingi likaingia uingereza', 5),
#  ('Baadhi wa wanajeshi wa Amin waliogopa kukabiliana na majeshi hayo ya kigeni',
#   5),
#  ('Halmashauri ya Manispaa ya Ilemela na halmashauri ya wilaya ya Kwimba', 5),
#  ('utaratibu wakuwakutanisha wanafunzi wote waliofanya vizuri katika', 5),
#  ('Pia kulikuwa na marefa wawili waliosimama nyuma ya magoli', 5),
#  ('siku ambayo hufanyika sherehe kubwa inayoambatana na burudani za ngoma za asili',
#   5),
#  ('hazihesabiki na zikifika ni zaidi ya filamu ya Arnold Schwarzenegger', 5),
#  ('Jina la wilaya limetokana na kituo cha misheni ya Moravian cha Rungwe', 5),
#  ('Mpandaji wa mlima huu anapitia kanda tofati za hewa', 5),
#  ('vinaongezeka kwa sababu imekuwa biashara kubwa', 5),
#  ('Halmashauri ya jiji la Tanga na halmashauri ya wilaya ya Muheza', 5),
#  ('Ni mataifa machache sana katika Afrika yaliyopata uhuru', 5),
#  ('Hawapendi kuonewa wala kumuonea mtu wanaamini katika haki sawa', 5),
#  ('Majimbo ya kaskazini yalishinda na kuwaweka huru watumwa', 5),
#  ('Ilipofika mwezi wa kumi na mbili mwaka elfu mbili alisainiwa Barcelona', 5),
#  ('Kiliripoti kuwa watu wengi walioacha kutumia matibabu', 5),
#  ('Hata hivyo idadi ya mifugo inapopungua hamu ya damu inakuwa ndogo', 5),
#  ('Urefu wa kilomita za elfu moja mia nne thelathini na tatu', 5),
#  ('Hali ambayo huenda ikawaweka katika hatari ya maambukizi ya virusi wapenzi wote wawili',
#   5),
#  ('mahale ni hifadhi yenye historia ya kuwa makazi ya jamii adimu za sokwe',
#   5),
#  ('ngorongoro ipo umbali wa kilomita mia moja na themanini kutokea jijini arusha',
#   5),
#  ('Akawaamasisha raia wake kuipenda na kuishangilia timu ya mpira wa Legger',
#   5),
#  ('mkuu wa majeshi ya uganda alikuwa mwingereza', 5),
#  ('mpango wa hili hautaishia kwa mchezaji kuishia kupata mazoezi ya kocha wa timu pekee',
#   5),
#  ('Bila ya kukutana kimwili hakuna uwezekano wa kupata maambukizi ya zinaa',
#   5),
#  ('kwa shambulio hilo Rais Obama alitoa rasmi idhini mapema', 5),
#  ('Aliamini matatizo ya Cuba ya kiuchumi yalikuwa ni matokeo ya ubepari', 5),
#  ('Anapowindwa na wanyama walao nyama kama simba hukosa uwezo wa kukimbia na hukamatwa kirahisi',
#   5),
#  ('Alitawala kiongozi aliyejulikana kwa jina la Mehinga', 5),
#  ('Milima mbalimbali imewekwa kwenye uhifadhi kulinda asili zake', 5),
#  ('wanawake wajawazito wanapaswa kwenda kliniki kila mwezi', 5),
#  ('Samaki hawa wanavunja rekodi ya uzito duniani', 5),
#  ('Kwa jumla inakadiriwa kuwa wapo wamasai takribani milioni mbili', 5),
#  ('Wanauchumi wa mfumo hutilia hisabati msisitizo mchache', 5),
#  ('wa hali ya wakati ujao', 5),
#  ('mfungaji bora wa michuano hiyo alitoka swideni', 5),
#  ('Na wakati huo sukari hujenga katika damu yako', 5),
#  ('Bila kujali tofauti za jinsia mtoto wa kike au wa kiume', 5),
#  ('Elagabali hata alimtuma simba wake na mbwa kwa vyumba vya wageni wake', 5),
#  ('sasa naye Nabii Ismail na huko akaoa', 5),
#  ('Tibaijuka alisisitiza kuwa anaona fahari kufanikisha mchango wa shule yake',
#   5),
#  ('aina mpya ya ushangiliaji wa mavuvuzela ulianza rasmi', 5),
#  ('Kwani imezungukwa na bahari kila upande wake', 5),
#  ('dhoruba ilikuwa kali sana katika kumbukumbu za kihistoria', 5),
#  ('Hasa wale wanaotibiwa hospitalini wakiwemo wanaofanyiwa upasuaji', 5),
#  ('Chukua vibebeo kama vile rambo weka vimengenywa vilivyopoa kisha weka mbegu za uyoga',
#   5),
#  ('Tanzania ilijibu mashambulizi hayo kwa kurusha makombora ambayo yaliharibu gari moja',
#   5),
#  ('alichaguliwa kuwa waziri wa mambo ya nje na benjamini mkapa', 5),
#  ('katika utawala wake hazipo tena Wasahau', 5),
#  ('Mlaji atawashwa midomo na ulimi kwa kula chakula hicho', 5),
#  ('Baada ya hapo mwanamke mgumba huondoka na mtoto wake kwenda kuanza maisha mapya',
#   5),
#  ('kupitia mishahara yao katika kipindi cha miezi kumi na mbili iliopita', 5),
#  ('Mkataba kati ya Uingereza na Ujerumani ulibana eneo', 5),
#  ('Pia wananchi wa maeneo hayo hasa wafanya biashara', 5),
#  ('Swala la hali ni muhimu.', 5),
#  ('ghana waliibuka mabingwa kwa ushindi kwa penati', 5),
#  ('nyerere alirudi dar es salaam akiwa na hofu kubwa sana', 5),
#  ('Kulikuwa na redio ndogo nasikiliza halafu nakwenda kwenye mkusanyiko wa wanafunzi',
#   5),
#  ('hiyo inaashiria wachoraji hao walikuwa wawindaji hasa', 5),
#  ('Sasa Amin alikuwa kanali na Mkuu wa Jeshi', 5),
#  ('Atawezaje kuwa na Mungu mwenyehuruma katika maisha yake', 5),
#  ('aneth aliongea akilifuata kabati la mafaili', 5),
#  ('Viongozi wa Kanisa wakaona hatari wakajaribu kumtisha anyamaze', 5),
#  ('Zikiwemo tafiti za madawa ya binadamu na wanyama', 5),
#  ('Baada ya kuondoka kwa Wajerumani Mkwawa aliweza kurudi', 5),
#  ('Utawala wake upo katika kiwango cha Pol Pot', 5),
#  ('Angela Vorobeva alithibitisha kwa watu wengi waliokuwa na wasiwasi wa kupanda mlima huu',
#   5),
#  ('Kwa ajili ya kujipatia kipato cha kuendesha maisha', 5),
#  ('blob anaweza kubadilisha tabia yake iliyozoeleka', 5),
#  ('na mila na desturi ya kabila lake', 5),
#  ('Lengo kuu la Amin lilikuwa kuchukua sehemu kubwa ya kaskazini mwa Tanzania',
#   5),
#  ('Maudhui ya nyimbo zake zikaanza kubadilika taratibu', 5),
#  ('Kinyume na nyoka wengine madume ni wakubwa kuliko majike.', 5),
#  ('Mji mkuu pia mji mkubwa wa jimbo ni Columbia.', 5),
#  ('Ndicho kitabu cha kwanza cha Wazungu kuhusu Wamongolia.', 5),
#  ('Mji huu upo katika Mkoa wa Anatolia ya Kati katika Uturuki.', 5),
#  ('Iko katika upande wa mashariki mwa Mlima Kenya.', 5),
#  ('Safu hiyo mara nyingi hujumuisha ufafanuzi juu ya habari.', 5),
#  ('Hakuna wanyama wakubwa wengi waliobaki mlimani', 5),
#  ('Kabila hili ni la kibantu waliopata kufika maeneo ya Udigo', 5),
#  ('Kabila dogo la kiislamu ambalo lilikuwa limewekwa katika eneo hilo', 5),
#  ('kutoka kwa kijana mdogo kama yule hilo lilimfanya atoke nje na kumuacha',
#   5),
#  ('Vita iyo ilikuwa ya Mzungu na Mwafrika popote pale walipokuwa wakikutana',
#   5),
#  ('Mto Nile wa Uganda Delta ya Okava ngo ya Bostwana na Jangwa la Sahara', 5),
#  ('Baadhi ya ndugu zake walikwenda kufanya kazi katika migodi ya Afrika Kusini',
#   5),
#  ('Hifadhi ya Taifa ya Serengeti Kijiografia inapatikana katika Mkoa wa Mara',
#   5),
#  ('Kaka Laurentius Brenner aliyapima baadhi ya mapango', 5),
#  ('katika karne ya ishirini na moja watoto wamekuwa wakipewa kipaumbele katika mambo mbalimbali',
#   5),
#  ('Hii inajidhihirisha wazi kutokana na kuwepo kwa makanisa mengi kuliko misikiti',
#   5),
#  ('John Raphael Bocco Mchezaji anayeongoza kwa magori toka ligi kuu Tanzania kuanzishwa',
#   5),
#  ('Wakati mwingine utawasikia wapare wenyewe wakisema samaki si kitu bali mchuzi ndio kila kitu',
#   5),
#  ('Lakini badae alimuoa mwanamama Graca Michael mjane', 5),
#  ('Alianzisha makambi ya mauaji pamoja na mateso dhidi ya watu wasiokuwa wajerumani',
#   5),
#  ('Eneo lote la mkoa lina kilometa elfu arobaini na moja mia tatu na kumi', 5),
#  ('Chakula chao hawali kitu kingine zaidi nyama', 5),
#  ('Alipoonekana mbele ya umma tangu augue', 5),
#  ('wamejikuta wakihamia kusini mwa Afrika', 5),
#  ('wachezaji wengi hawakufunga mabao kwenye michuano hiyo', 5),
#  ('Katika shule za kizungu waliongezeka wakaendeleza Mapamabano', 5),
#  ('walikubali Mkwawa kuwa chifu wa wahehe', 5),
#  ('Karibu na Ngâiriama mto unatoka katika Usangu na kuingia hifadhi ya kitaifa ya Ruaha',
#   5),
#  ('eneo hilo lililokuwa na mifupa na mafuvu ilisemekana kuwa ya twiga na viboko',
#   5),
#  ('Wakati wa kipindi hicho cha mabadilishano ya biashara', 5),
#  ('Kisha akanyoosha juu mkono wake wa kulia ambao tayari ulikuwa umeandikwa namba',
#   5),
#  ('Ili kupata hali halisi ya safari yenu ya matembezi', 5),
#  ('Ni baada ya hifadhi ya Taifa ya Ruaha kuongezwa ukubwa', 5),
#  ('Muungano huo ulishuhudiwa na viongozi wa mataifa yote mawili', 5),
#  ('kuna baadhi ya dalili zinaweza kujitokeza kwenye ngozi', 5),
#  ('Iliyotolewa mwaka wa elfu moja mia tisa tisini na nane', 5),
#  ('Abeid Karume na ujumbe wake wa chama cha Afro Shirazi kutoka Zanzibar', 5),
#  ('wananchi wa tanzania wanazalisha vyakula vingi sana', 5),
#  ('walinunua kisiwa kutoka kwa aliyekuwa sultani wa zanzibar', 5),
#  ('Mlima Meru wenye urefu wa mita elfu nne mia tano sitini na sita', 5),
#  ('pep guardiola hawezi kwenda china kwa sasa', 5),
#  ('Amin jinsi alivyopanda vyeo jeshini Ufalme wa Muungano', 5),
#  ('Mafuta ya nyama hutumika katika kupika sana uji mahindi na maharagwe', 5),
#  ('Na safari yake ya mwisho ilianzia Dar es saalam', 5),
#  ('miaka yote hiyo baada ya kuwakomboa watu wake', 5),
#  ('Inayotokana na maumbile ya mibuyu inayosadikiwa kuwa na umri mrefu', 5),
#  ('mpira ulimpa maisha mazuri cristian ronaldo', 5),
#  ('Kwa mujibu wa orodha iliyotolewa jana Jumanne', 5),
#  ('Alihitimu Shahada ya Kingereza Baada ya hapo alienda Marekani na kusomea diplomasia',
#   5),
#  ('Mashamba na mali zao zilitaifishwa bila kufidiwa', 5),
#  ('Alikuwa kiongozi wa Wilaya mbili Wilaya ya Rufiji na Wilaya ya Mufindi', 5),
#  ('rais wa kwanza wa kenya alikuwa jomo kenyatta', 5),
#  ('Kongamano nililotangulia kulitaja washiriki pia walitoa mwito', 5),
#  ('mfumo mzima wa uongozi wa nchiya tanzania unaiweka huru', 5),
#  ('ya kunywa kwani maziwa ya mama yanavirutubisho', 5),
#  ('Kutunza familia kwa umakini jambo linatoa tumaini kwa mwendelezo wa kizazi chake',
#   5),
#  ('Kazi ya uanamitindo ina changamoto nyingi mwanamke asipopata mume anayeielewa biashara hii atakwama',
#   5),
#  ('Taarifa hii ilitangazwa moja kwa moja na Rais John Pombe Magufuli', 5),
#  ('Baada ya sehemu hiyo kukamilika kutengenezwa chifu mtarajiwa hupitishwa kwa nyuma',
#   5),
#  ('kutawazwa kwa Mhalwike utawala huo ukapinduliwa na mmoja', 5),
#  ('nchi nyingi za afrika na duniani zilipata uhuru wake kwa silaha', 5),
#  ('bao la kwanza la maradona lilikuwa la mkono wa mungu', 5),
#  ('na mujahideen inadaiwa kuwa shirika la kijasusi la Marekani', 5),
#  ('Umaarufu wa hifadhi hii unaweza kuuona kwa kiasi', 5),
#  ('Ya mwaka elfu moja mia tisa sabini na saba sura ya kwanza', 5),
#  ('Alizuiliwa kwa maandamano ya wananchi walioipinga hatua hiyo', 5),
#  ('Walioathirika na wasiojali kitu huku vikundi vya ndege aina ya tai', 5),
#  ('Wakati bunge Uganda lilitaka utafiti kuhusu mashtaka ya Obote kushiriki katika biashara ya siri',
#   5),
#  ('Hata hivyo miezi kadhaa baadaye alitafuta msaada wa Wajerumani kwa shambulio dhidi ya Wabena',
#   5),
#  ('Ilianzishwa wakati wa kugawa Usultani wa Omani', 5),
#  ('Alionekana kuelemewa Karume akamwita Mzee Mtoro Rehani', 5),
#  ('Iliundwa ili kusimamia usambazaji wa noti na sarafu', 5),
#  ('Lakini makampuni makubwa ya nje yanakuja kuwekeza katika upande wa sekta hii ya maji',
#   5),
#  ('Awali alikuwa alishika jina hili kutafakari ahadi yake ya kuikomboa nchi',
#   5),
#  ('united wana mafanikio makubwa sana Ulaya', 5),
#  ('Kulingana na serikali za nchi na nyingine zinapotea zenyewe taratibu', 5),
#  ('bidii katika kazi inaleta maendeleo manzuri kwa kila mtu katika jamii', 5),
#  ('Huwa wanaonekana wakiwa katika himaya yao', 5),
#  ('Alicheza timu za Manchester United na nyengine nyingi japo timu ya taifa ya Uingereza',
#   5),
#  ('manchester united ikicheza fainali inashinda', 5),
#  ('Taifa la Cuba liligeuka kuwa uwanja wa mapamabano ya vita baridi vya dunia',
#   5),
#  ('Mnamo miaka ya elfu moja mia tisa sabini', 5),
#  ('karim benzema ndiye aliyemliza pep guardiola', 5),
#  ('Amri za rais decrees ndizo zilizotawala nchi', 5),
#  ('Pundamilia ni moja wa wanyama wanaoambatana na nyumbu wakati wakihama', 5),
#  ('nyerere alizikwa kijijini butiama alipozaliwa', 5),
#  ('Ngorongoro Crater caldera ya volkeno kubwa zaidi ulimwenguni hupatikana',
#   5),
#  ('Uwepo wa misitu husababisha rangi ya maji kubadilika', 5),
#  ('Ambapo ndama laki nne huzaliwa katika kipindi cha wiki sita', 5),
#  ('waliweza kupata masalia mbalimbali yaliyotumiwa na watu wa kale', 5),
#  ('Na liporejea nchini aliajiriwa kuwa afisa mipango visiwani Zanzibari', 5),
#  ('anatumikia Argentina na Klabu yake ya Barcelona', 5),
#  ('Walijiona wamedanganywa kwa kutotimiziwa ahadi walizopewa ili Wasaliti Ujerumani na Hungaria',
#   5),
#  ('Vivyo hivyo nyakati za jioni wakirudi majumbani', 5),
#  ('dunia inawataja guardiola na ferguson kuwa makocha bora zaidi', 5),
#  ('mafanikio huletwa na vijana wanaoweza kupambana', 5),
#  ('Warangi inaonekana walitoka sehemu za magharibi', 5),
#  ('Muyinga mufwimi akaanza kutawala akazaa watoto watatu wa kiume Maliga Nyenza na Mpondwa',
#   5),
#  ('Maana isiyo rasmi huu ni uzushi tu wa watu fulani kutaka kuwachafua waswahili',
#   5),
#  ('Siasa mpya ya Glasnost iliruhusu kutoa maoni mbalimbali', 5),
#  ('Kisiwa cha Mafia ni sehemu ya visiwa vya Bahari ya Hindi', 5),
#  ('Mchezo wa kriketi ni maarufu na pia ni mchezo wa timu ambao umefaulu sana',
#   5),
#  ('Wamasai humwabudu Mungu pekee nao humwita Enkai au Engai', 5),
#  ('Mwenge unaendelea kukimbizwa hadi sasa', 5),
#  ('ambayo unaweza kuisababisha ni vyema ukasikiliza Kwanza', 5),
#  ('Ikiwa na jumla ya Rangi nne za kupendeza sana', 5),
#  ('Adui wa nyumbu ni simba na mamba', 5),
#  ('wahadzabe ni kabila lenye hadithi nyingi za kustaajabisha', 5),
#  ('watu wengi walimsifia kwa kuona maendeleo makubwa ya tanzania', 5),
#  ('Tanzania ina aina mbili za mavazi yanayojulikana kokote nchini', 5),
#  ('mkataba wa daraja la mkapa rufiji ulisainiwa na mzee mwinyi', 5),
#  ('Watu mbali mbali wamejaribu kuliongelea hili', 5),
#  ('Akiwa na umri wa miaka kumi na saba aliingia katika Chuo Kikuu cha Erfurt',
#   5),
#  ('miguu ya mbuni ina manyoya hadi vidoleni', 5),
#  ('fungo alitoa wito kwa wananchi wa jiji hilo kuendelea kutumia fursa hiyo',
#   5),
#  ('Kisiwa hiki ni mahali pazuri pa kupiga mbizi uvuvi au kupumzika', 5),
#  ('Inawezekana hii kiasili ilikuwa kaldera iliyojaa lava', 5),
#  ('Vimengenywa hivi hutumika kama mbolea shambani na katika bustani', 5),
#  ('Kutokana na wasiwasi kuhusu idadi ya simba nchini', 5),
#  ('usambara ni milima iliyoshikana kutoka mlima mmoja mpaka mwingine', 5),
#  ('Asilimia sabini na mbili ya watoto walikuwa hawana meno ya kusagia', 5),
#  ('Hali kadhalika anafanya biashara ya usafirishaji mizigo', 5),
#  ('viumbe wengi wa kushangaza walitokea ndani ya miaka thelathini', 5),
#  ('Mgogoro ulipozidi kukua mashambulizi yakahama sasa', 5),
#  ('Mauzo ya Tanzanite duniani yanafikia takribani dola za Marekani milioni hamsini',
#   5),
#  ('hajawahi kutokea beki kushinda tuzo ya mchezaji bora wa dunia', 5),
#  ('Wabende na Wabondei pamoja na Wabungu au Wawungu', 5),
#  ('wakati huo George Bush kuwa atalipa kisasi kwa mtindo', 5),
#  ('amewekwa kwenye bustani ya paris nchini ufaransa', 5),
# ...
#   5),
#  ('Pua ni ndefu na masikio ni makubwa na ya mviringo.', 5),
#  ('Alikuwa na kaka na dada sita.', 5),
#  ('Hata hivyo idadi ya wasemaji inaendelea kukua.', 5),
#  ('Watoto wawili wa ziada walifariki wakiwa wachanga.', 5),
#  ('Yeye ndiye mzaliwa wa mwisho katika familia yake.', 5),
#  ('Kwa hiyo, lugha hiyo imekaribia kutoweka kabisa.', 5),
#  ('Hupiga gumzo na huweka akiba ya chakula', 5),
#  ('Historia yake ilisomwa na Viongozi waliohudhuria siku hiyo', 5),
#  ('kwa ajili ya kutibu magonjwa ya aina mbalimbali', 5),
#  ('Ningependa kuelezea masikitiko yangu kwa kumpoteza kijana wa Afrika', 5),
#  ('Magufuli ndiye waziri pekee aliyekuwa akiweza kumfanyia utani', 5),
#  ('Mkoa wa tabora Umepakana na mikoa jirani ya Mwanza na Shinyanga', 5),
#  ('Mwaka elfu moja mia tisa sitini na moja Luteni', 5),
#  ('Kwa hakika walisaidia wakati wa harakati za Uhuru', 5),
#  ('Na kuimarika kwa soko la dhahabu nchini humo', 5),
#  ('majangili wanahitaji ngozi na pembe za wanyamapori', 5),
#  ('Kumpungia mkono asiyewaona tena mvua na jua vilikuwa vyao bila kujali', 5),
#  ('maria htakiwi kuogopa wala kuwa na hofu', 5),
#  ('Mwenye pesa anaweza kuufanya mlima everist kuwa bonde', 5),
#  ('Mtu anapaswa kufanya uamuzi wa kuingia katika uhusiano wa kimapenzi', 5),
#  ('bao la pili la Maradona lilikuwa tamu sana', 5),
#  ('Patrice Lumumba alitoa hotuba yake ya kwanza kama Waziri mkuu', 5),
#  ('Wanakaa pamoja na kushirikiana mambo mbalimbali katika jamii yao', 5),
#  ('Palikuwa na biashara kiasi samaki na chumvi', 5),
#  ('raisi kikwete alikaa madarakani kwa miaka kumi', 5),
#  ('Akafuta Ntare wa tano wengi wakizoea kumuita Kiitabanyoro', 5),
#  ('Mfano madereva kwa ajili ya kuendesha magari ya kubeba mizigo', 5),
#  ('watu wanajifunza vitu vingi sana kwenye maonyesho ya sabasaba', 5),
#  ('obotte ndiye aliyepinduliwa na idd amini', 5),
#  ('Streika huyo alianza kuicheza Ligi Kuu Bara msimu wa mwaka elfu mbili na nane',
#   5),
#  ('Ni Mungu aliyewawekea wanadamu mazingira ya kuvutia na kustaajabisha ili tuweze kujifunza',
#   5),
#  ('jose mourinho alikuwa bora sana zamani', 5),
#  ('watu Waliyoshitakiwa alikuwa nahodha na mkuu wa bandari ya kemondo', 5),
#  ('nahodha wa brazil alikuwa carlos dunga', 5),
#  ('Hivyo uwepo wa Ziwa Turkana imesaidia sana kutatua shida ya maji kwa wananchi wake',
#   5),
#  ('Wanyambo hupenda kula ndizi kama chakula chao', 5),
#  ('Na umiliki ukahamishiwa kwenye mamlaka hiyo rasmi', 5),
#  ('Walihamia huko Wakushi kutoka kaskazini nao wakameza kwa kiasi kikubwa wakazi asili',
#   5),
#  ('Pia mgonjwa anapewa mfumo wa maisha ambao anatakiwa autumie', 5),
#  ('kuwa jumuiya hile ilikuwa chombo cha makabaila wakubwa', 5),
#  ('Alijifahamisha kati ya wa mijikenda huko pwani', 5),
#  ('Pamoja na halmashauri ya wilaya ya Butiama', 5),
#  ('Zenye tani elfu kumi na tano mia nne hamsini na tano', 5),
#  ('na alama rahisi za mafanikio iliyokuwa', 5),
#  ('Mikakati hii ni pamoja na kuwakutanisha wadau wa mkongo huu', 5),
#  ('Huanza kidogo lakini huongezeka na huwa mwingi na kusababisha kusikia haja ya kukojoa',
#   5),
#  ('barcelona ilitisha lakini haikuwahi kufanya kama arsenal ya wenger', 5),
#  ('waarabu kutoka omani walihamia bagamoyo na kukuza biashara zao hapo', 5),
#  ('hakuna tume huru iliyoundwa kuchunguza kifo cha kiongozi huyo', 5),
#  ('Mwaka elfu moja mia tisa hamsini na nane', 5),
#  ('tanzania ilikuwa katika misingi bora kwenye uongozi wa mwalimu', 5),
#  ('Wakazi wa asili wa Mkoa wa Mara ni makabila makuu mawili yenye uhusiano',
#   5),
#  ('Maeneo hayo ni kama vile Ruvu Makanya Mabilioni na kadhalika', 5),
#  ('Sherehe zinapoanza huwa wanatoka ndani na vichwa vyao hunyolewa', 5),
#  ('Alifarika tarehe kumi na nne Oktoba mwaka elfu moja mia tisa tisini na tisa',
#   5),
#  ('Hasimu wa Messi kwenye soka ni Ronaldo', 5),
#  ('Kijiji hicho kilichopo umbali wa takribani kilometa moja kutoka Kilwa Masoko',
#   5),
#  ('Nakumbuka walinipa mwongozo wa kipindi wa kusoma ulikuwa na majina ya Kichina',
#   5),
#  ('Wadau wa sekta ya Utalii ambao ni serikali na jamii', 5),
#  ('Ambao baadhi yao ni za wafanyakazi wa huduma ya afya', 5),
#  ('mjini Johannesburg Watanzania wengi', 5),
#  ('Funga kamba vibebeo kuzuia bakteria na hewa isiingie kirahisi kwenye vimengenywa',
#   5),
#  ('Alikuwa mwanamasumbwi wa uzito wa juu', 5),
#  ('Mikumi inajaribu kulinganishwa mara kwa mara na tambarare maarufu za Serengeti',
#   5),
#  ('Inafahamika kama mamlaka ya hifadhi ya Ngorongoro kabla ya eneo la Ngorongoro kutenganishwa',
#   5),
#  ('Kufuatana na uainishaji wa lugha kwa ndani zaidi, Kibirifor-Kusini iko katika kundi la Kigur.',
#   5),
#  ('Watu fulani au kuonyesha tu baadhi ya vipengele vya ugonjwa wa kawaida', 5),
#  ('Imepakana na Korea Kusini, China na Urusi.', 5),
#  ('Walikuwa hodari sana katika astronomia yaani elimu ya nyota.', 5),
#  ('Kamusi elezo hii imegawanyika katika vitabu vingi sana.', 5),
#  ('Linafuata mapokeo ya Antiokia na kutumia liturujia ya Antiokia.', 5),
#  ('Ni hasa eneo la rasi kati ya Bahari Nyeusi na Mediteranea.', 5),
#  ('Chakula pia ni muhimu kwa utunzaji wa ngozi.', 5),
#  ('Yeye hana asili nyingine na Yeye ndiye sababu kuu ya sababu zote.', 5),
#  ('Eurafrica pia inaendelea kuwa na athari kubwa kwa Ulaya na biashara ya Uropa.',
#   5),
#  ('Sultan wa Oman akashika nchi Baada ya hapo', 5),
#  ('Kilipata usajili tarehe thealathini Agosti elfu moja mia tisa arobaini', 5),
#  ('Bibi Titi alikaririwa siku moja akisema', 5),
#  ('Nyota ilingaa alipogombea na kushinda ubunge jimbo la Chato', 5),
#  ('ingawa mvua inaweza kunyesha mwezi Novemba Kuna', 5),
#  ('Na hao ndio wana elimu ya kimtaala na waliipata vyema', 5),
#  ('Mlima Elgoni unapatiakana katika taifa la Kenya pia', 5),
#  ('kuanzia mwaka elfu moja mia nane themanini na nne', 5),
#  ('Matukio hayo yalikuwa yakionyeshwa pande zote za dunia', 5),
#  ('baadhi ya mila na desturi za wabena zinashabihiana', 5),
#  ('Haya yanapaswa kutunzwa na kutumiwa ipasavyo kwa kutembelewa', 5),
#  ('Wapare ni kabila kutoka milima ya Pare Mkoani wa Kilimanjaro', 5),
#  ('Pia kwa Bandari ya Tanga iliopo kaskazini mwa nchi', 5),
#  ('nahod wa ureno alikuwa nyota mkongwe luis Figo', 5),
#  ('wewe humjuhi vizuri malatwe tuulize sisi tukupe habari', 5),
#  ('Zao la korosho linadhibitiwa na bodi ya korosho Tanzania', 5),
#  ('Mojawapo ya jitihada zake ni upanuzi wa elimu', 5),
#  ('mtoto malatwe anatoa machozi kila kukicha', 5),
#  ('Daima kuna maswali makuu manne Nani nini wapi lini', 5),
#  ('Waziri wa Afya Maendeleo ya Jamii Jinsia Wazee na Watoto ni Ummy Mwalimu',
#   5),
#  ('Dagaa hupatikana kwenye ziwa victoria ziwa Tanganyika na ziwa nyasa', 5),
#  ('Lazima nchi yake itawaliwe na waafrika wenyewe wala sio watu wengine', 5),
#  ('Alipata habari ya kwamba mdogo wake Mpangile alishikamana na Wajerumani',
#   5),
#  ('Huku wengine wakijiajiri wenyewe katika shughuli za uchimbaji wa madini',
#   5),
#  ('Waarabu wa Omani hawakuwa na uwezo wa kupingana na jeshi la wanamaji la Uingereza',
#   5),
#  ('Jina la kwanza ni Mwita ambalo asili yake ni uguita', 5),
#  ('Kwa ujumla makoloni yote yasiyokuwa na jeshi yalitekwa', 5),
#  ('Hawakujulikana kama kabila la Waha na hawakuja', 5),
#  ('Milima ya Nsasi na Milima ya Nyaburuma', 5),
#  ('Mwaka elfu moja mia tisa hamsini na mbili alihitimu shahada ya uzamili', 5),
#  ('Boma la zamani ni moja ya majengo ya kuvutia katika mji mkongwe', 5),
#  ('lazima kwenda nchi nyingine bali hata safari', 5),
#  ('Hebu tuone baadhi ya makabila kumi tuu ambayo yana wanawake wazuri zaidi Tanzania',
#   5),
#  ('kilemile alifafanua kuwa lugha ni moja', 5),
#  ('Watoto hufaria michezo.', 5),
#  ('Hivyo kufanya makazi katika eneo hili la kijiji cha Wapimbwe', 5),
#  ('wengi waliamini kuwa ukatili aliyoufanya zilikuwa ni mbinu za kumchafua',
#   5),
#  ('Mlipuko ulitokea kasoko kwenye kilele cha kibo', 5),
#  ('senegal iliyokuwa na wakali kama nyota wa liverpool sadio mane', 5),
#  ('Mo alizaliwa tarehe nane Mei mwaka elfu moja mia tisa sabini na tano', 5),
#  ('Kwa sababu wamezungukwa na rasilimali ya maji', 5),
#  ('Japo ukiwa Shinyanga napo utawasikia watu wa Shinyanga wakisema wao wapo kaskazini',
#   5),
#  ('Wamasai wengi wameacha maisha ya wahamaji na kupata nafasi', 5),
#  ('Kwa kawaida hutoka kwa Wandorobo ambao ndio hufanya tohara hizo', 5),
#  ('Pembeni ya msikiti huo kulikuwa na makaburi', 5),
#  ('Na kuziamishia familia zao moja kwa moja huku Afrika', 5),
#  ('Samia alikamilisha masomo ya shule ya upili miaka kadhaa iliyopita', 5),
#  ('Ilianza kufa na awali Tembo ambao hula miti michanga na mizee', 5),
#  ('chadema ina viongozi wabobezi wa siasa', 5),
#  ('Wilaya Ngorongoro ni mojawapo ya wilaya sita zilizopo katika Mkoa wa Arusha',
#   5),
#  ('Tawala za kijamaa zilianguka kote duniani', 5),
#  ('Akapewa kadi namba kumi na sita', 5),
#  ('liverpool walifanya kama mahasimu wao manchester united', 5),
#  ('Wapiga picha za wanyamapori na hakuna shughuli kuu', 5),
#  ('Ambayo ni Msimu wa Vuli unaoanzia mwezi Oktoba Desemba', 5),
#  ('vyura wa jozani ni vyura wa kipekee wanaopatikana jozani pekee', 5),
#  ('hivi ulishawahi kuona physics inafundishwa madrasa', 5),
#  ('Pia uwepo wa hifadhi hizi kumewavutia sana wawekezaji', 5),
#  ('Kukubalika na kuheshimiwa kwake kunategemea uwezo alionao', 5),
#  ('Wamekadiriwa kuwa ni watu themanini hivi', 5),
#  ('Ustawi wa hifadhi hii hutegemea kwa kiasi kikubwa', 5),
#  ('dunia imejaa maadui wanaotaka kuifanya tanzania maskini', 5),
#  ('katika Wilaya saba za Mkoa wa Pwani', 5),
#  ('Wareno walikuja Zanzibar lakini utawala wao ulifuatiwa na kutokuwepo utulivu',
#   5),
#  ('Aliwahi pia kuwa baharia kwa hiyo baadhi ya vitabu vyake vilieleza', 5),
#  ('brazil ikasimika ufalme wa soka ulimwenguni', 5),
#  ('vimesababisha watoto wengi kutotambuliwa mpaka kufikia umri wa miezi mitatu',
#   5),
#  ('Kuendelea na wadhifa huo wa waziri kiongozi', 5),
#  ('Tanzania na Kenya zimepitia kitambo hicho sio tu miaka ya nyuma', 5),
#  ('Sithole anafundisha jeshi lake binafsi nchini Uganda', 5),
#  ('wale wanaokula viumbe hai vidogo sana baharini hawana meno bali mifupa ya kinywani',
#   5),
#  ('bielsa haogapi kucheza soka la kushambulia', 5),
#  ('Wilaya inashirikiana na wadau mbalimbali waliopo wilayani katika kuendeleza sekta ya kilimo',
#   5),
#  ('Shimo la ajabu lijulikanalo kama Shimo la Mungu wilayani Newala', 5),
#  ('diego maradona alifariki mwaka jana nchini kwao argentina', 5),
#  ('Uhamiaji huo ni moja ya maajabu kumi ya asili ya ulimwengu ya kusafiri', 5),
#  ('somo la itikadi lilimkolea kichwani kuliko masomo mengine aliyokuwa ankiyasoma',
#   5),
#  ('Bahari hii imekuwa ni kichocheo kikubwa cha uchumi kwa bara la Afrika', 5),
#  ('Mnyama huyo miguu yake ni mirefu inamsaidia kupambana na maadui', 5),
#  ('Upande wa magharibi wa mkoa mito mingi ina mwaga maji yale katika Mto Kagera',
#   5),
#  ('Baadhi ya Watanzania maarufu kutoka kabila la Wajita ni Daktari Chinuno Magoti',
#   5),
#  ('Ni eneo la mapumziko kwa wageni watokao sehemu mbalimbali duniani', 5),
#  ('na Nyerere Bibi Titi akamwambia Nyerere kuwa', 5),
#  ('Aliingizwa kwenye Baraza Wakikuyu waliamua kuanzisha chama chao cha kwanza',
#   5),
#  ('ndege maji na mimea yenye kutoa harufu nzuri inapatikana kwa wingi rubondo',
#   5),
#  ('kujumuisha maeneo hayo ndani ya Hifadhi ya Taifa Ziwa Manyara', 5),
#  ('Tanzania ina mikoa mingi sana na mkoa wenye shughuli nyingi ni Dar es salaam',
#   5),
#  ('Wakati wote huo alikuwa pia ni Mwenyekiti wa Taifa wa Chama cha Mapinduzi',
#   5),
#  ('Vita Kuu ya Pili ya Dunia ilikuwa vita iliyodumu kwa muda', 5),
#  ('mfungaji bora wa kombe la dunia alikuwa muingereza', 5),
#  ('Maalim Self aliteuliwa kuwa waziri kiongozi wa serikali ya mapinduzi Zanzibari',
#   5),
#  ('kilimo ndiyo uti wa mgongo wa watanzania wengi', 5),
#  ('chama cha mapinduzi kiliendelea kukaa madarakani kwa awamu ya tano', 5),
#  ('Hii inajumuisha ujenzi wa hoteli za kitalii na ufugaji wa vipepeo', 5),
#  ('kaa ukijua safari yako inaweza isifanikiwe kwa namna moja au nyingine', 5),
#  ('mtoto kupata afya bora wataalam wanachambua zaidi', 5),
#  ('Wataalamu wa masuala ya benki wamemwambia mwandishi wa makala haya', 5),
#  ('Baadhi ya matukio aliyoyasimulia katika wimbo huo', 5),
#  ('kuwa mpenzi mwaminifu kwa sasa yako utaona', 5),
#  ('Mfano ni soko la samaki linalopatikana katika mji wa Dar es salaam nchini Tanzania',
#   5),
#  ('njia za kuutunza uso wako ni kuukinga na chunusi', 5),
#  ('Baadhi ya makabila ya Kenya yalipinga ujenzi huo hasa Wanandi', 5),
#  ('Akaanzisha tawi la Umoja wa wanafunzi Watanganyika', 5),
#  ('kutoka kwa Ukoloni wa waingereza akiwa pamoja na', 5),
#  ('watu hushughulikia malengo mbalimbali wakidhania watapata maana', 5),
#  ('Ujenzi wa majengo yao ulitegemea zaidi mawe na matumbawe yakiunganishwa',
#   5),
#  ('Kiuhalisia kesi ni njia mojawapo ya kuhakikisha haki inatendeka katika jamii',
#   5),
#  ('nchi za ughaibuni wakija kutalii maeneo haya', 5),
#  ('pep alipofika ujerumani alifanya kama alivyokuwa hispania', 5),
#  ('Waliishi pamoja na wanyama pori wengi huku wakikataa kula wanyama hao', 5),
#  ('ufugaji mbaya wa mifugo unaharibu uoto wa asili', 5),
#  ('Miingiliano wa watu toka sehemu mbalimbali za nchi kufuata fursa zilizopo Sumbawanga',
#   5),
#  ('mwanasayansi einstein alizaliwa karne moja iliyopita', 5),
#  ('alizaliwa katika eneo la milimani la Transkei nchini Afrika Kusini', 5),
#  ('anajenga timu inayotafuta ushinda wa mataji', 5),
#  ('Malengelenge katika sehemu za siri husababisha vivimbe vinavyouma vinavyojirudia kila mara',
#   5),
#  ('jike linalopendelewa na dume huatamia mayai yote', 5),
#  ('Mshambulizi wa kimataifa wa uingereza gary lineker aliibuka mfungaji bora wa michuano',
#   5),
#  ('Shule ya pili ya Mkwawa inapatikana Iringa', 5),
#  ('kutokana na kukua kwa utalii wa ndani ambapo wananchi hupenda kwenda', 5),
#  ('Ili kupata taarifa kuhusu uzuiaji wa virusi vya Ukimwi', 5),
#  ('Kanuni ya shirika pia ilikuwa inadai padri asome na kutafakari Biblia', 5),
#  ('Walipokaa kwenye pwani walikuwa karibu na makazi ya Waswahili wakaanza kufahamiana na Waislamu',
#   5),
#  ('Aina fulani ya bata huwa wanaogelea humo kwa wingi', 5),
#  ('Wakapita Tabora na maeneo ya Ujiji kwenda Ziwa Tanganyika', 5),
#  ('Tumejipanga kuhakikisha katika Jiji la Dodoma tunafanya kilimo cha mjini',
#   5),
#  ('nigeria waliandaa michuano iliyofuatia ya bara la afrika', 5),
#  ('Alihudhuria mkutano wa Bunge la Kitaifa la India', 5),
#  ('Kuvifanya ndiyo makao makuu kwa safari', 5),
#  ('Ikiwa ni juhudi za kupiga vita ufisadi na ubadhirifu', 5),
#  ('mourinho aliwahi kujiondosha porto na inter milan', 5),
#  ('pia ameisaidia Simba kuchukua kombe la Ngao ya Jamii ambapo waliifunga Azam',
#   5),
#  ('Wabilikimo Wa kwanza wanaendelezwa na wajukuu wao', 5),
#  ('alibadilisha jina lake kuwa amin dada', 5),
#  ('chato ni wilaya ya mkoa wa geita', 5),
#  ('Hii ni katiba mpya baada ya muungano wa Tanganyika na Zanzibari', 5),
#  ('Ukoo huu hauvumi sana kutokana na watoto wa wazee hao kuhama', 5),
#  ('kuimarisha uhuru na amani pamoja na kuandaa itikadi na sera za kuondoa ujinga',
#   5),
#  ('Mlima Makanja na Milima ya Makos bila kusahau Mlima Makungwini', 5),
#  ('nchini tanzania hakuna ubaguzi wa rangi', 5),
#  ('Wapo watu ambao wanaingia ndani ya hifadhi', 5),
#  ('Kwa asili walikuwa wafugaji na hivyo walihamahama', 5),
#  ('siku hizi mourinho hatishi kama miaka iliyopita', 5),
#  ('mtu yeyote anashauriwa kumpiga picha tembo bila flash', 5),
#  ('nyerere alikuwa raisi wa kwanza wa tanzania', 5),
#  ('kukomeshwa kwa utawala wa kibaguzi Afrika kusini', 5),
#  ('kwa upande mwingine magofu yamegeuka kuwa rasilimali muhimu katika sekta ya utalii',
#   5),
#  ('Baadhi ya wazee wanadhaniwa kuwa wachawi na wamekuwa wakiogopwa', 5),
#  ('Kila sababu yakutafuta kamera yako ili upige picha za ukumbusho', 5),
#  ('Iliwafanya wakoloni kumlazimisha Nyerere kuchagua kati ya siasa na kazi ya ualimu',
#   5),
#  ('Nkrumah yeye alipendelea kusoma London huko nchini Uingereza', 5),
#  ('maafisa wa serikali ya uganda hawakusema chochote', 5),
#  ('Wanaoingia nchini kwa mara ya kwanza baada ya utalii wa wanyamapori na ufukweni',
#   5),
#  ('Linapakana na wilaya ya Ulanga na wilaya ya Kilombero', 5),
#  ('ilindwe na vikosi vya kiislam Aliahidi kutoa', 5),
#  ('wananchi wanafikisha matatizo yao wanapokutana na viongozi', 5),
#  ('vyama vya siasa nchini tanzania vinachuana miaka yote katika chaguzi', 5),
#  ('Wakati huo Wahehe walikuwa wameimarisha himaya yao', 5),
#  ...]

# %% [markdown]
#  Gender dynamics

# %%
set(validated['gender'])
set(validated['age'])
# Out:
# {'fifties', 'fourties', nan, 'sixties', 'teens', 'thirties', 'twenties'}

# %%
print('train/dev/test set gender dynamics')
print(Counter(list(train['gender'].append(dev['gender']).append(test['gender']))))
print(' ')
print('validated set gender dynamics')
print(Counter(list(validated['gender'])))
print(' ')
print('Entire set gender dynamics ie. validated + unvalidated')
print(Counter(list(validated['gender'].append(invalidated['gender']).append(other['gender']))))
# Out:
# train/dev/test set gender dynamics
# Counter({nan: 15427, 'male': 11025, 'female': 10900})
#
# validated set gender dynamics
# Counter({'male': 43865, nan: 34921, 'female': 20947})
#
# Entire set gender dynamics ie. validated + unvalidated
# Counter({'male': 182190, 'female': 151413, nan: 111588})

# %% [markdown]
# Age dynamics

# %%
print('train/dev/test set age dynamics')
print(Counter(list(train['age'].append(dev['age']).append(test['age']))))
print(' ')
print('validated set age dynamics')
print(Counter(list(validated['age'])))
print(' ')
print('Entire set age dynamics ie. validated + invalidated + other')
print(Counter(list(validated['age'].append(invalidated['age']).append(other['age']))))
# Out:
# train/dev/test set age dynamics
# Counter({'twenties': 18343, nan: 15704, 'thirties': 1748, 'fourties': 765, 'fifties': 756, 'sixties': 35, 'teens': 1})
#
# validated set age dynamics
# Counter({'twenties': 45864, nan: 35400, 'thirties': 15253, 'fourties': 1680, 'fifties': 1464, 'sixties': 71, 'teens': 1})
#
# Entire set age dynamics ie. validated + invalidated + other
# Counter({'twenties': 199794, nan: 126716, 'thirties': 65442, 'fifties': 28169, 'fourties': 21782, 'sixties': 3152, 'teens': 136})

# %%
DataFrame(set(validated['sentence'].append(invalidated['sentence']).append(other['sentence'])))
# .to_csv('cv-sw-for-tts.txt', header=None, index=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-bc28f64adf2d> in <module>
# ----> 1 DataFrame(set(validated['sentence'].append(invalidated['sentence']).append(other['sentence'])))
#       2 # .to_csv('cv-sw-for-tts.txt', header=None, index=None)
#
# NameError: name 'DataFrame' is not defined

# %%
train
# Out:
#                                                client_id  \
# 0      fa923498f56bd5b96add49ff651d75142835ec60748579...
# 1      fa923498f56bd5b96add49ff651d75142835ec60748579...
# 2      fa923498f56bd5b96add49ff651d75142835ec60748579...
# 3      fa923498f56bd5b96add49ff651d75142835ec60748579...
# 4      fa923498f56bd5b96add49ff651d75142835ec60748579...
# ...                                                  ...
# 19601  457b3a2570720101c75d297cde767487e8f0a1a7f714cb...
# 19602  457b3a2570720101c75d297cde767487e8f0a1a7f714cb...
# 19603  457b3a2570720101c75d297cde767487e8f0a1a7f714cb...
# 19604  457b3a2570720101c75d297cde767487e8f0a1a7f714cb...
# 19605  457b3a2570720101c75d297cde767487e8f0a1a7f714cb...
#
#                                path  \
# 0      common_voice_sw_28704519.mp3
# 1      common_voice_sw_28704543.mp3
# 2      common_voice_sw_28704555.mp3
# 3      common_voice_sw_28704557.mp3
# 4      common_voice_sw_28704588.mp3
# ...                             ...
# 19601  common_voice_sw_30062381.mp3
# 19602  common_voice_sw_30063221.mp3
# 19603  common_voice_sw_30065486.mp3
# 19604  common_voice_sw_30067147.mp3
# 19605  common_voice_sw_30128422.mp3
#
#                                                 sentence  up_votes  \
# 0                       Spishi zote zinatokea Afrika tu.         2
# 1      Kiebrania kilikuwa lugha ya Israeli ya Kale wa...         2
# 2      Wakati mwingine inaweza kutokea bila kuleta ma...         2
# 3                   Gregori wa Tours aliandika juu yake.         2
# 4               Aliwahi kucheza timu ya taifa ya Uswisi.         2
# ...                                                  ...       ...
# 19601  Pamoja masalia ya viwanda vya chuma katika ene...         2
# 19602  joto la baharini lina viwango vya juu vya unye...         2
# 19603  Hata hivyo ni lazima wakati huo huo sisi kuzin...         2
# 19604  Yanaweza yakaashiria dalili za maambukizi ya v...         2
# 19605  Inawezekana kwamba maisha ya kisasa imefanya y...         2
#
#        down_votes       age  gender  accents locale  segment
# 0               0  twenties  female      NaN     sw      NaN
# 1               0  twenties  female      NaN     sw      NaN
# 2               0  twenties  female      NaN     sw      NaN
# 3               0  twenties  female      NaN     sw      NaN
# 4               0  twenties  female      NaN     sw      NaN
# ...           ...       ...     ...      ...    ...      ...
# 19601           1  thirties    male      NaN     sw      NaN
# 19602           0  thirties    male      NaN     sw      NaN
# 19603           0  thirties    male      NaN     sw      NaN
# 19604           0  thirties    male      NaN     sw      NaN
# 19605           0  thirties    male      NaN     sw      NaN
#
# [19606 rows x 10 columns]

# %%
dist = Counter(list(validated['sentence'].append(invalidated['sentence']).append(other['sentence']))).values()

# %%
fig, axs = plt.subplots()
axs.plot(sorted(dist, reverse=True))
fig.savefig('repetitions')

# %%
dist
# Out:
# dict_values([28, 29, 6, 29, 30, 29, 28, 29, 29, 29, 29, 6, 6, 29, 28, 29, 29, 29, 29, 29, 29, 29, 29, 28, 29, 6, 6, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 28, 29, 6, 6, 6, 29, 30, 29, 7, 7, 7, 7, 29, 29, 29, 29, 7, 7, 7, 7, 29, 29, 30, 29, 28, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 28, 28, 29, 28, 29, 29, 29, 29, 29, 28, 29, 28, 6, 6, 29, 29, 29, 31, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 29, 28, 28, 29, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 6, 6, 6, 6, 6, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 6, 6, 6, 6, 6, 6, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 30, 29, 28, 29, 28, 29, 29, 28, 28, 30, 29, 29, 30, 29, 29, 29, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 30, 29, 28, 29, 29, 28, 29, 28, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 29, 29, 30, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 29, 29, 28, 28, 28, 29, 28, 28, 29, 29, 29, 29, 29, 28, 28, 29, 29, 28, 28, 28, 28, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 28, 29, 29, 29, 28, 29, 28, 28, 29, 29, 29, 29, 28, 28, 28, 29, 29, 28, 29, 28, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 28, 29, 29, 29, 29, 29, 28, 29, 29, 29, 29, 29, 29, 29, 6, 6, 6, 6, 28, 29, 29, 29, 29, 28, 28, 28, 29, 28, 28, 29, 29, 28, 28, 28, 28, 28, 28, 29, 28, 29, 29, 28, 28, 28, 28, 29, 28, 28, 28, 28, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 5, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 28, 29, 28, 29, 29, 29, 28, 28, 28, 28, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 30, 29, 29, 29, 28, 28, 29, 29, 29, 28, 29, 29, 29, 28, 28, 29, 28, 29, 29, 29, 29, 29, 29, 29, 29, 28, 28, 29, 28, 28, 29, 28, 28, 29, 29, 28, 29, 29, 29, 28, 29, 29, 29, 29, 29, 29, 28, 29, 28, 29, 28, 29, 28, 28, 28, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 28, 29, 29, 28, 29, 28, 28, 29, 28, 29, 28, 29, 28, 29, 28, 28, 28, 29, 28, 28, 28, 29, 28, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 29, 28, 29, 28, 28, 28, 28, 29, 29, 28, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 30, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 28, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 29, 30, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 29, 28, 28, 28, 29, 29, 28, 29, 29, 29, 29, 29, 29, 29, 28, 28, 28, 29, 28, 28, 28, 28, 28, 28, 28, 28, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 29, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 29, 29, 28, 28, 28, 28, 28, 29, 28, 28, 28, 29, 28, 29, 28, 28, 28, 29, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 28, 6, 6, 6, 7, 6, 6, 6, 7, 7, 6, 7, 6, 7, 7, 6, 7, 6, 6, 6, 6, 7, 7, 6, 6, 7, 6, 7, 6, 7, 6, 6, 6, 6, 6, 7, 6, 6, 6, 6, 7, 6, 7, 7, 7, 7, 6, 29, 29, 30, 29, 29, 29, 30, 30, 29, 29, 29, 28, 29, 29, 29, 29, 29, 29, 29, 29, 30, 29, 29, 30, 29, 29, 29, 30, 29, 30, 28, 28, 28, 29, 30, 29, 29, 29, 29, 29, 29, 29, 29, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
