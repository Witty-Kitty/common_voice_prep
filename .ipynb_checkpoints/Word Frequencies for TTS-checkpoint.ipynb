# %%
import os
import string
from collections import Counter

# %% [markdown]
# open several txt files into one string

# %%
all_txt_files = sorted(os.listdir('TTS'))
text = ''

for txt in all_txt_files:
    txt_dir = 'TTS/' + txt
    with open(txt_dir, 'r') as txt_file:
        text += txt_file.read()

# %% [markdown]
# 1. split at newline characters
# 2. remove empty strings from the list
# 3. split at whitespace to get words, then flatten the now nested list
# 4. remove empty strings from list
# 5. lower all the caps
# 6. remove punctuation
# 7. do a word count, create word-frequency pairs

# %%
# 1
text_list = content.splitlines()
# 2
while("" in text_list) :
    text_list.remove("")
# 3
nested_list = [string.split(" ") for string in text_list]
flat_list = [nest for sublist in nested_list for nest in sublist]
#4
while("" in flat_list) :
    flat_list.remove("")
# 5
lowered_list = [string.lower() for string in flat_list]
#6
clean_list = [''.join(letter for letter in word if letter not in string.punctuation) for word in lowered_list]
# 7
word_count = [clean_list.count(word) for word in clean_list]
word_freq = list(zip(clean_list,word_count))

# %%
Counter(clean_list)
# Out:
# Counter({'jina': 24,
#          'langu': 11,
#          'ni': 261,
#          'rebecca': 7,
#          'ryakitimbo': 7,
#          'watu': 59,
#          'wengi': 83,
#          'hupata': 4,
#          'taabu': 4,
#          'katika': 414,
#          'kutamka': 4,
#          'na': 1266,
#          'kuandika': 13,
#          'la': 112,
#          'mwisho': 16,
#          'kwani': 41,
#          'lililo': 4,
#          'lugha': 214,
#          'ya': 1078,
#          'asili': 24,
#          'wazanaki': 4,
#          'mimi': 17,
#          'nilizaliwa': 4,
#          'kijiji': 4,
#          'cha': 85,
#          'nyamuswa': 4,
#          'mkoa': 4,
#          'wa': 813,
#          'musoma': 4,
#          'kisha': 14,
#          'kukulia': 4,
#          'mji': 18,
#          'arusha': 4,
#          'uliopo': 4,
#          'kaskazini': 7,
#          'mwa': 10,
#          'tanzania': 16,
#          'nilijiunga': 10,
#          'masomo': 59,
#          'chuo': 28,
#          'kikuu': 28,
#          'eldoret': 4,
#          'pale': 25,
#          'nchini': 25,
#          'kenya': 35,
#          'kusomea': 4,
#          'digrii': 4,
#          'uhandisi': 12,
#          'teknolojia': 198,
#          'mawasiliano': 17,
#          'electroniki': 4,
#          'wakati': 37,
#          'nikiwa': 4,
#          'niligundua': 4,
#          'yakuwa': 4,
#          'wanawake': 86,
#          'hawakuwa': 4,
#          'wakisomea': 4,
#          'wakiwa': 4,
#          'mtazamo': 7,
#          'kuwa': 147,
#          'kazi': 140,
#          'au': 68,
#          'yanayofaa': 4,
#          'zaidi': 70,
#          'jinsia': 61,
#          'kiume': 7,
#          'hii': 183,
#          'ilinipa': 4,
#          'changamoto': 65,
#          'kubwa': 25,
#          'hasa': 41,
#          'waliposhangaa': 4,
#          'kumuona': 8,
#          'mwanamke': 16,
#          'anapanda': 8,
#          'minara': 8,
#          'simu': 20,
#          'kutengeneza': 14,
#          'vifaa': 49,
#          'vya': 52,
#          'kielektroniki': 4,
#          'vilipoharibika': 4,
#          'hivyo': 56,
#          'nilipokuwa': 13,
#          'chuoni': 10,
#          'nilitumia': 4,
#          'muda': 29,
#          'mwingi': 15,
#          'wanaume': 13,
#          'nilikuwa': 7,
#          'pekee': 11,
#          'aliyekuwa': 4,
#          'akisomea': 4,
#          'hali': 31,
#          'niliikuta': 4,
#          'hata': 23,
#          'nilipohitimu': 4,
#          'kujiunga': 13,
#          'ambapo': 36,
#          'yangu': 37,
#          'kwanza': 30,
#          'ilikuwa': 36,
#          'kampuni': 25,
#          'kutoa': 16,
#          'huduma': 31,
#          'intaneti': 21,
#          'mara': 22,
#          'nyingi': 40,
#          'wangeshangaa': 4,
#          'kuwarekebishia': 4,
#          'mitandao': 32,
#          'hapo': 7,
#          'ndipo': 7,
#          'nilipoamua': 4,
#          'maswala': 21,
#          'muhimu': 49,
#          'kwangu': 28,
#          'kama': 182,
#          'sekta': 15,
#          'inanipasa': 4,
#          'kujaribu': 4,
#          'kuwavuta': 4,
#          'kuwajuza': 4,
#          'haina': 13,
#          'mnamo': 11,
#          'mwaka': 49,
#          '2016': 4,
#          'nikishirikiana': 4,
#          'wenzangu': 14,
#          'waliokuwa': 7,
#          'wakifanya': 4,
#          'mbalimbali': 25,
#          'za': 370,
#          'sayansi': 29,
#          'tulianzisha': 4,
#          'kikundi': 19,
#          'techchix': 4,
#          'tulitumia': 7,
#          'kuhamasisha': 4,
#          'wasichana': 7,
#          'kuto': 4,
#          'kuogopa': 4,
#          'zetu': 25,
#          'zilipata': 4,
#          'kujulikana': 7,
#          'ikatuwezesha': 4,
#          'kundi': 7,
#          'kushinda': 4,
#          'tuzo': 13,
#          '“malkia': 4,
#          'nguvu”': 4,
#          '2018': 7,
#          '2017': 4,
#          'nili': 4,
#          'bahatika': 4,
#          'kuchaguliwa': 11,
#          'mmoja': 13,
#          'washiriki': 10,
#          'mkutano': 19,
#          'mkuu': 4,
#          'jukwaa': 13,
#          'utawala': 19,
#          'mtandao': 93,
#          'geneva': 4,
#          'uswisi': 4,
#          'kule': 4,
#          'nilijifunza': 8,
#          'juu': 25,
#          'jinsi': 58,
#          'bado': 19,
#          'wako': 4,
#          'nyuma': 19,
#          'sera': 34,
#          'nilichukua': 4,
#          'ile': 13,
#          'kuamua': 4,
#          'kuleta': 4,
#          'fursa': 63,
#          'kwa': 381,
#          'afrika': 58,
#          'mashariki': 7,
#          'mwanzilishi': 8,
#          'mwenza': 4,
#          'shule': 54,
#          'ijulikanayo': 4,
#          'kigeni': 17,
#          '“arusha': 4,
#          'women': 7,
#          'school': 4,
#          'of': 10,
#          'internet': 4,
#          'governance”': 4,
#          'hivi': 29,
#          'sasa': 30,
#          'yapata': 4,
#          'miaka': 19,
#          'minne': 4,
#          'toka': 4,
#          'kuanza': 16,
#          'kila': 71,
#          'tunawafikia': 4,
#          'wengine': 22,
#          'nafurahi': 4,
#          'ninapoona': 4,
#          'wanajihusisha': 4,
#          'kutetea': 4,
#          'haki': 16,
#          'zao': 41,
#          'kidijitali': 28,
#          'ulinzi': 4,
#          'usalama': 11,
#          'taarifa': 22,
#          'unyanyasaji': 13,
#          'kijinsia': 28,
#          'kupitia': 60,
#          'shirika': 25,
#          'icannwiki': 8,
#          'kuhusu': 55,
#          'kutafsiri': 37,
#          'maneno': 19,
#          'kitaalamu': 7,
#          'kutoka': 46,
#          'kiingereza': 37,
#          'kwenda': 7,
#          'kiswahili': 146,
#          'nilipata': 13,
#          'balozi': 4,
#          'mradi': 80,
#          'wao': 4,
#          'wiki': 10,
#          'kiswahiliubalozi': 4,
#          'huu': 101,
#          'uliamusha': 4,
#          'upendo': 7,
#          'niliokuwa': 4,
#          'nao': 10,
#          'ikanikumbusha': 4,
#          'utoto': 4,
#          'wangu': 19,
#          'ndo': 4,
#          'iliyo': 10,
#          'zungumzwa': 4,
#          'nyumbani': 4,
#          'jamii': 56,
#          'iliyonizunguka': 4,
#          'shuleni': 13,
#          'kanisani': 4,
#          'sokoni': 4,
#          'taifa': 4,
#          'ilinifanya': 4,
#          'kumkumbuka': 4,
#          'rafiki': 8,
#          'aliesomea': 4,
#          'msingi': 13,
#          'serikali': 14,
#          'kukosa': 7,
#          'bahati': 4,
#          'kuendeleza': 34,
#          'masoma': 4,
#          'yake': 22,
#          'alio': 4,
#          'ijua': 4,
#          'nikafanya': 4,
#          'utafiti': 25,
#          'kuona': 22,
#          'kurasa': 4,
#          'kumejaa': 4,
#          'dhana': 7,
#          'maudhui': 8,
#          'sio': 13,
#          'mwenzangu': 10,
#          'tuliamua': 4,
#          'toleo': 4,
#          'lingekuwa': 4,
#          'madhumuni': 7,
#          'mafundisho': 4,
#          'programu': 51,
#          'mengineyo': 4,
#          'mpaka': 4,
#          'tumeweza': 10,
#          'kuwafundisha': 4,
#          'umuhimu': 13,
#          'zilizo': 16,
#          'juzi': 4,
#          'tuliweza': 4,
#          'miongozo': 4,
#          'mandaoni': 4,
#          'iliyotengenezwa': 4,
#          'internews': 4,
#          'jana': 4,
#          'tulitafsiri': 4,
#          'psiphon': 4,
#          'iliyowasaidia': 4,
#          'kupata': 52,
#          '2020': 7,
#          'nchi': 22,
#          'ilizima': 4,
#          'kipindi': 7,
#          'uchaguzi': 4,
#          'mozilla': 49,
#          'ninapata': 4,
#          'nafasi': 31,
#          'kufanya': 49,
#          'vitu': 4,
#          'viwili': 4,
#          'ninavyovipenda': 4,
#          'kukuza': 37,
#          'pili': 10,
#          'kuongeza': 13,
#          'ushirika': 4,
#          'tofauti': 31,
#          'matumizi': 41,
#          'sauti': 89,
#          'ninajua': 4,
#          'kwamba': 82,
#          'ndugu': 4,
#          'zinazonizunguka': 4,
#          'hazitakosa': 4,
#          'kushiriki': 10,
#          'tehama': 4,
#          'saidizi': 4,
#          'zikiwa': 4,
#          'mama': 7,
#          'mahojiano': 3,
#          'kati': 30,
#          'mwandishi': 6,
#          'george': 12,
#          'githuma': 12,
#          'njogu': 6,
#          'kevin': 9,
#          'omondi': 3,
#          'ambaye': 3,
#          'meneja': 12,
#          'wachangiaji': 15,
#          'chanzo': 15,
#          'wazi': 42,
#          'common': 30,
#          'voice': 30,
#          'nani': 6,
#          'mtafiti': 3,
#          'fani': 3,
#          'mhadhiri': 3,
#          'kisayansi': 3,
#          'tarakilishi': 6,
#          'pia': 66,
#          'mchangiaji': 3,
#          'vyanzo': 3,
#          'vile': 33,
#          'ambao': 30,
#          'tuelezee': 3,
#          'ulivyopata': 3,
#          'kuhusika': 3,
#          'kujua': 15,
#          '2019': 3,
#          'msimamizi': 6,
#          'shahada': 3,
#          'falsafa': 3,
#          'dk': 3,
#          'tom': 3,
#          'denton': 3,
#          'google': 36,
#          'tulijadialiana': 3,
#          'mambo': 21,
#          'mengi': 15,
#          'mashine': 33,
#          'zinavyoweza': 3,
#          'kufunzwa': 3,
#          'binadamu': 36,
#          'ndivyo': 6,
#          'ilivyoibuka': 3,
#          '': 18,
#          'nia': 3,
#          'mjadiliano': 3,
#          'huo': 9,
#          'ilikua': 3,
#          'kujenga': 24,
#          'injini': 3,
#          'utambuzi': 9,
#          'kuifanya': 3,
#          'iwe': 6,
#          'ukiangalia': 3,
#          'tangu': 6,
#          'ulipoanza': 3,
#          'kuchangia': 12,
#          'swahili': 9,
#          'hadi': 18,
#          'nini': 15,
#          'unaweza': 6,
#          'kusema': 9,
#          'yamekuwa': 3,
#          'mafanikio': 9,
#          'yako': 3,
#          'makubwa': 6,
#          'yamekua': 3,
#          'kuweza': 15,
#          'kufufua': 3,
#          'haswa': 9,
#          'hapa': 30,
#          'nairobi': 6,
#          'baada': 21,
#          'kutokuwepo': 6,
#          'mrefu': 3,
#          'lakini': 45,
#          'kukutana': 9,
#          'eunice': 3,
#          'manyasi': 3,
#          'hildagard': 3,
#          'msuya': 3,
#          'victoria': 3,
#          'nyamai': 3,
#          'joan': 3,
#          'wambui': 3,
#          'wengineo': 3,
#          'walioweza': 3,
#          'kujitoa': 3,
#          'kujitolea': 6,
#          'kutaka': 6,
#          'inakua': 3,
#          'athari': 6,
#          'nzuri': 9,
#          'siku': 42,
#          'zijazo': 6,
#          'zipi': 3,
#          'ambazo': 69,
#          'umepitia': 3,
#          'unapoangalia': 3,
#          'kwenye': 69,
#          'safari': 3,
#          'nitaziita': 3,
#          'chanya': 3,
#          'pamoja': 42,
#          'kutenga': 3,
#          'mbali': 54,
#          'zangu': 9,
#          'ili': 48,
#          'michango': 6,
#          'saa': 12,
#          'nyingine': 12,
#          'hupunguka': 3,
#          'hujihusisha': 3,
#          'mengine': 6,
#          'kushawishi': 3,
#          'wajiunge': 3,
#          'usiokuwa': 3,
#          'zawadi': 6,
#          'kifedha': 3,
#          'imekua': 3,
#          'ikinila': 3,
#          'kichwa': 3,
#          'tukiongelea': 3,
#          'vipi': 6,
#          'umeweza': 3,
#          'kutatua': 9,
#          'hizi': 54,
#          'njia': 18,
#          'moja': 51,
#          'ambayo': 51,
#          'nimetumia': 3,
#          'kutafuta': 15,
#          'wenye': 15,
#          'muonekano': 3,
#          'walioko': 3,
#          'tayari': 9,
#          'hawa': 6,
#          'kubadilishana': 3,
#          'mawazo': 6,
#          'maarufu': 3,
#          'mojawapo': 9,
#          'kompyuta': 42,
#          'zaweza': 3,
#          'funzwa': 3,
#          'kuelewa': 30,
#          'tuelezea': 3,
#          'umefikia': 3,
#          'wapi': 12,
#          'kinaendelea': 3,
#          'vizuri': 3,
#          'kinaweza': 3,
#          'kuboreshwa': 3,
#          'una': 6,
#          'awamu': 15,
#          'tatu': 18,
#          'inafanyika': 3,
#          'ukurasa': 9,
#          'pontoon': 3,
#          'kupokea': 3,
#          'inasaidia': 6,
#          'tovuti': 15,
#          '86': 3,
#          'imefanyika': 3,
#          'inaendelea': 3,
#          'kufanyika': 3,
#          'uchangiaji': 3,
#          'sentensi': 30,
#          'zitatumika': 9,
#          'kufunza': 21,
#          '9000': 3,
#          'zimechangishwa': 3,
#          'kuidhinishwa': 3,
#          'kuchapishwa': 3,
#          'commonvoicemozillaorgsw': 3,
#          'zinatumika': 3,
#          'uchangishaji': 3,
#          'udhibitishaji': 3,
#          'uko': 3,
#          'inatarajiwa': 3,
#          'kuisha': 3,
#          'mwishoni': 3,
#          'unadhani': 3,
#          'utachangia': 6,
#          'nzima': 6,
#          'natural': 6,
#          'language': 6,
#          'processing': 6,
#          'nlp': 3,
#          'kiafrika': 36,
#          'hutengwa': 3,
#          'rasilimali': 9,
#          'kuzifanyia': 3,
#          'ujanibishaji': 3,
#          'kufundisha': 9,
#          'kawaida': 15,
#          'huongea': 3,
#          'itakuwa': 15,
#          'ushindi': 3,
#          'mkubwa': 6,
#          'itaweza': 6,
#          'duniani': 6,
#          'kujifunza': 3,
#          'miezi': 6,
#          'mitatu': 6,
#          'ijayo': 6,
#          'unatarajia': 3,
#          'umefika': 3,
#          'gani': 12,
#          'ungependa': 6,
#          'kuyaona': 3,
#          'mfupi': 3,
#          'sana': 66,
#          'nitasema': 3,
#          'ningependa': 9,
#          'hifadhidata': 12,
#          'imezinduliwa': 3,
#          'itawasaidia': 3,
#          'watafiti': 9,
#          'kuchambua': 3,
#          'mashini': 3,
#          'kuna': 21,
#          'chochote': 3,
#          'nashukuru': 3,
#          'mtu': 45,
#          'jumuiya': 3,
#          'msaada': 6,
#          'tuliyopata': 3,
#          'imekuwa': 6,
#          'raha': 3,
#          'timu': 6,
#          'natumai': 6,
#          'zinaonekana': 3,
#          'kwetu': 9,
#          'sote': 6,
#          'dhidi': 3,
#          'mbili': 12,
#          'awali': 3,
#          'wangeifanya': 3,
#          'inaweza': 3,
#          'kufanywa': 3,
#          'yaani': 12,
#          'ina': 21,
#          'uwezo': 30,
#          'tafsiri': 45,
#          'wetu': 45,
#          'wamepata': 3,
#          'kutumia': 54,
#          'translate': 21,
#          'imeundwa': 6,
#          'mwanafunzi': 6,
#          'kifaransa': 15,
#          'nilitegemea': 3,
#          'ziada': 3,
#          'zilizohitaji': 3,
#          'nitunge': 3,
#          'kusoma': 15,
#          'hadithi': 6,
#          'mazoezi': 3,
#          'kuzungumza': 6,
#          'nilipopata': 3,
#          'neno': 18,
#          'ambalo': 9,
#          'silifahamu': 3,
#          'rahisi': 9,
#          'kupiga': 3,
#          'chapa': 6,
#          'hilo': 9,
#          'mazungumzo': 39,
#          'kufikiria': 6,
#          'nilipotaka': 3,
#          'sifahamu': 3,
#          'ningepiga': 3,
#          'hili': 36,
#          'nilichohitaji': 3,
#          'urahisi': 3,
#          'haiko': 3,
#          'sawa': 12,
#          'zote': 12,
#          'dunia': 3,
#          'tukiingia': 3,
#          'yasiyopo': 3,
#          'karibuni': 3,
#          'nimekuwa': 9,
#          'hamu': 18,
#          'kiluhya': 3,
#          'nimehuzunishwa': 3,
#          'ukosefu': 6,
#          'ambavyo': 12,
#          'vingerahisisha': 3,
#          'juhudi': 15,
#          'kumi': 6,
#          'zinazopatikana': 9,
#          'wazungumzaji': 24,
#          'takriban': 3,
#          'milioni': 12,
#          'mia': 18,
#          'hamsini': 9,
#          'inayoinufaisha': 3,
#          'kidigitali': 9,
#          'makampuni': 12,
#          'hutia': 3,
#          'maanani': 6,
#          'wanaamini': 3,
#          'idadi': 6,
#          'kulinganisha': 6,
#          'zingine': 21,
#          'tunapata': 6,
#          'kina': 3,
#          'utendaji': 3,
#          'kiwango': 15,
#          'zina': 6,
#          'imechangia': 3,
#          'kuzingatiwa': 3,
#          'kuwepo': 15,
#          'zinafanya': 3,
#          'hakumaanishi': 3,
#          'haziwezi': 6,
#          'makosa': 9,
#          'zinahitaji': 3,
#          'kufikiri': 3,
#          'zinazofanywa': 6,
#          'ngumu': 9,
#          'kuiga': 6,
#          'wataalamu': 12,
#          'wanaohusiana': 3,
#          'mada': 6,
#          'hufanywa': 3,
#          'utaalamu': 3,
#          'unaojulikana': 3,
#          'akili': 6,
#          'bandia': 3,
#          'artificial': 3,
#          'intelligence': 3,
#          'wanaendeleza': 3,
#          'haijafika': 3,
#          'kuchukua': 6,
#          'harakati': 9,
#          'kutayarisha': 3,
#          'makala': 18,
#          'blogi': 6,
#          'tunachapisha': 3,
#          'nimejipata': 3,
#          'nikifanya': 6,
#          'nikawa': 3,
#          'ningepata': 3,
#          'ingelingana': 3,
#          'ningeifanya': 3,
#          'mwenyewe': 3,
#          'niliyotafsiri': 3,
#          'haya': 18,
#          '“kuwezesha': 3,
#          'uvumbuzi': 93,
#          'kiasilia': 36,
#          'ulimwengu': 21,
#          'kusini': 18,
#          'matarajio': 6,
#          'kusonga': 6,
#          'mbele”': 3,
#          'madokezo': 3,
#          'haielewi': 3,
#          'vyema': 3,
#          'ngeli': 12,
#          'nimepata': 6,
#          'uhakika': 6,
#          'uelewano': 3,
#          'zinavyofaa': 3,
#          'kuingiliana': 3,
#          'mfano': 21,
#          'this': 3,
#          'initiative': 3,
#          'aims': 3,
#          'to': 6,
#          'support': 3,
#          'local': 6,
#          'innovation': 12,
#          'approaches': 3,
#          'that': 3,
#          'are': 3,
#          'empowering': 3,
#          'and': 12,
#          'inclusive': 3,
#          'african': 12,
#          'stakeholders': 3,
#          'mpango': 36,
#          'unalenga': 6,
#          'kusaidia': 21,
#          'mbinu': 12,
#          'ndani': 9,
#          'zinawezesha': 3,
#          'kujumuisha': 3,
#          'wadau': 9,
#          'unakusudia': 6,
#          'mpya': 12,
#          'zinazowezesha': 6,
#          'kuhusisha': 6,
#          'unaonyesha': 9,
#          'imekosa': 3,
#          'kubadilisha': 3,
#          '‘uvumbuzi’': 3,
#          'huundwa': 3,
#          'kutegemea': 3,
#          'zinapatikana': 9,
#          'kutungwa': 3,
#          'inawezekana': 3,
#          'yetu': 30,
#          'hatuzingatii': 3,
#          'kuchanganya': 3,
#          'kupoteza': 3,
#          'maana': 21,
#          'inayotafsiriwa': 3,
#          'ikiwa': 3,
#          'ndefu': 3,
#          'how': 3,
#          'race': 3,
#          'nationality': 3,
#          'class': 3,
#          'biases': 3,
#          'limit': 3,
#          'the': 3,
#          'opportunities': 3,
#          'available': 3,
#          'innovators': 3,
#          'by': 3,
#          'foreign': 3,
#          'companies': 3,
#          'investors': 3,
#          'ubaguzi': 12,
#          'rangi': 3,
#          'utaifa': 9,
#          'tabaka': 3,
#          'unavyopunguza': 3,
#          'wavumbuzi': 15,
#          'wawekezaji': 9,
#          'upendeleo': 9,
#          'mbari': 6,
#          'kitabaka': 6,
#          'unavyowekea': 6,
#          'mipaka': 9,
#          'zinazoletwa': 6,
#          'refu': 3,
#          'inapoteza': 3,
#          'kabisa': 3,
#          'viungo': 3,
#          'vingi': 3,
#          'yanahitaji': 3,
#          'umakini': 3,
#          'kuhifadhi': 18,
#          'dhahiri': 3,
#          'zinaweza': 15,
#          'kutofautiana': 3,
#          'kuchagua': 9,
#          'visawe': 3,
#          'yaliyo': 3,
#          'eneo': 18,
#          'lingine': 3,
#          'linahitaji': 3,
#          'umakinifu': 6,
#          'kudhihirisha': 3,
#          'linalokubalika': 3,
#          'kisemantiki': 3,
#          'kutamatisha': 3,
#          'kusisitiza': 3,
#          'wazo': 9,
#          'hazifai': 3,
#          'muktadha': 3,
#          'kurahisisha': 3,
#          'wanaofanya': 6,
#          'tunayotamani': 3,
#          'kuiendeleza': 6,
#          'kujitambulisha': 6,
#          'kathleen': 12,
#          'siminyu': 9,
#          'introducing': 3,
#          'myself': 3,
#          'nina': 3,
#          'nimewahi': 3,
#          'yanishangaza': 3,
#          'inahisi': 3,
#          'kana': 6,
#          'geni': 3,
#          'pengine': 9,
#          'si': 3,
#          'jambo': 6,
#          'kushangaza': 3,
#          'nianze': 3,
#          'nikizungumza': 3,
#          'mwenendo': 3,
#          'ukaendelea': 3,
#          'vivyo': 3,
#          'upili': 12,
#          'nilifunzwa': 3,
#          'darasani': 3,
#          'wanafunzi': 15,
#          'wote': 9,
#          'wanaopitia': 3,
#          'zinazofuata': 3,
#          'mtaala': 3,
#          'elimu': 21,
#          'nje': 15,
#          'darasa': 6,
#          'kunipata': 3,
#          'nikiizungumza': 3,
#          'tulikuwa': 12,
#          'tunatarajia': 3,
#          'kuketi': 3,
#          'mitihani': 3,
#          'kitaifa': 3,
#          'tungekuwa': 3,
#          'maalum': 3,
#          'kututumainisha': 3,
#          'kujieleza': 3,
#          'ijumaa': 3,
#          'kulikuwa': 6,
#          'kutuza': 3,
#          'sababu': 18,
#          'vipengele': 3,
#          'aliyepata': 3,
#          'aliitwa': 3,
#          '‘bingwa': 3,
#          'kiswahili’': 3,
#          'angetarajiwa': 3,
#          'kusimama': 3,
#          'mbele': 6,
#          'umati': 3,
#          'insha': 3,
#          'iliyomtunuku': 3,
#          'niliwahi': 3,
#          'kulishinda': 3,
#          'nilipofika': 3,
#          'kilikuwa': 3,
#          'somo': 6,
#          'nililong’ang’ana': 3,
#          'nalo': 3,
#          'haikosi': 3,
#          'kutozungumza': 3,
#          'kutoitumia': 3,
#          'karatasi': 3,
#          'fasihi': 3,
#          'ndio': 6,
#          'iliyonipa': 3,
#          'msukumo': 3,
#          'mwishowe': 3,
#          'nilifaulu': 3,
#          'hicho': 3,
#          'nimewapa': 3,
#          'maelezo': 3,
#          'binafsi': 6,
#          'ingawa': 6,
#          'inasemekana': 3,
#          'tuna': 3,
#          'ustadi': 6,
#          'ndizo': 3,
#          'zinazotumika': 3,
#          'kutiliwa': 3,
#          'tunapoingia': 3,
#          'mazingira': 15,
#          'nilipojiunga': 3,
#          'nilisoma': 3,
#          'hesabu': 15,
#          'mwanzoni': 3,
#          'niliridhishwa': 3,
#          'yaliyohusiana': 6,
#          'kuliko': 15,
#          'kufaulu': 9,
#          'kulihitaji': 3,
#          'nijikaze': 3,
#          'yalikuwa': 6,
#          'magumu': 3,
#          'kuhitimu': 6,
#          'nilianza': 3,
#          'uwanja': 18,
#          'kitaaluma': 12,
#          'ningefanya': 3,
#          'uhusishe': 3,
#          'nilihisi': 3,
#          'nimeng’ang’ana': 3,
#          'kutoyatumia': 3,
#          'nilivyogundua': 3,
#          'data': 63,
#          'niliamua': 3,
#          'mfulizo': 3,
#          'kadhaa': 6,
#          'yaliyodhibitiwa': 6,
#          'yaliyoandaliwa': 3,
#          'edxedxorg': 3,
#          'courseracourseraorg': 3,
#          'bure': 3,
#          'yaliniridhisha': 3,
#          'nikaamua': 3,
#          'nilitaka': 3,
#          'mwanasayansi': 6,
#          'nilifanikiwa': 3,
#          'inayojulikana': 3,
#          'africa’s': 6,
#          'talking': 6,
#          'maarifa': 9,
#          'kufuatana': 3,
#          'walinipatia': 3,
#          'kuhudhuria': 3,
#          'mikutano': 3,
#          'warsha': 18,
#          'yaliyoleta': 3,
#          'wakazi': 3,
#          'mfanyakazi': 3,
#          'nilishirikiana': 3,
#          'waliofanya': 3,
#          'kuandaa': 15,
#          'kinachojulikana': 3,
#          'in': 6,
#          'machine': 9,
#          'learning': 6,
#          'science': 3,
#          'kilichowasaidia': 3,
#          'kujielimisha': 6,
#          'kuingia': 3,
#          'kuendelea': 6,
#          'nilijipata': 3,
#          'kuchunguza': 6,
#          'unaoitwa': 3,
#          'learningml': 3,
#          'unaohusiana': 9,
#          'karibu': 3,
#          'linavyodokeza': 3,
#          'inahusisha': 6,
#          'tuseme': 3,
#          'kujitawala': 3,
#          'picha': 3,
#          'kadri': 3,
#          'mamilioni': 3,
#          'ama': 12,
#          'bilioni': 3,
#          'paka': 3,
#          'zile': 3,
#          'wanaokimbia': 3,
#          'ml': 6,
#          'yanayoenea': 3,
#          'maisha': 9,
#          'hususan': 3,
#          'tunaotumia': 3,
#          'kielectroniki': 3,
#          'wale': 6,
#          'wanaotumia': 3,
#          'barua': 3,
#          'pepe': 3,
#          'iwapo': 6,
#          'umeona': 3,
#          'pendekezo': 3,
#          'kabla': 9,
#          'hujamaliza': 3,
#          'kutunga': 3,
#          'hiyo': 6,
#          'utumizi': 9,
#          'ninafanya': 3,
#          'unaojulukana': 3,
#          'namna': 18,
#          'wanawasiliana': 3,
#          'kumekuwa': 3,
#          'maendeleo': 6,
#          'lengo': 3,
#          'kuhakikisha': 24,
#          'haziachwi': 3,
#          'kuunda': 3,
#          'kutuwezesha': 3,
#          'kutimika': 3,
#          'baadaye': 9,
#          'tutachunguza': 3,
#          'faida': 3,
#          'mkazi': 3,
#          'kilifi': 9,
#          'kuweka': 6,
#          'wakfu': 3,
#          'mwalimu': 3,
#          ...})

# %% [raw]
# word_freq
