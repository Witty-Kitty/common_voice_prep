# %%
import pandas

# %%
df = pandas.read_csv('kiswahili_dialects_data/kibajuni/sentences.csv')

# %%
df0.dropna().to_csv('sw-kibajuni.txt', header=None, index=None)

# %%
df.columns  = ['566', '1', '2', '3', '4',
       '5', '6', '7', '8']
# ['143', 'two']

# %%
df = df.drop(df.tail(200).index)

# %%
df
# Out:
#                                                    566  \
# 0                               Haye veneve hamuyambo?
# 1    Ukipacha nchu eyavo Lamu mpe hao isi anechee nami
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 556                       Ubavo uliojepwa umepachikana
# 557               Baba huchumia kijembe kunyolea ndevu
# 558      Ali ameumwa na mbuvo mpaka amepekwa sipichali
# 559                   Kengele a sukuli hulia kwa nguvu
# 560              Vanavake huchumia ibafe kufulia nguvo
#
#                        Unnamed: 1        Unnamed: 2  Unnamed: 3  \
# 0                     Hamna neno?  Mame nae ukeiye?  Na vanave?
# 1    Isi hula wali nkavuu nchupuu               NaN         NaN
# 2                             NaN               NaN         NaN
# ...

# %%
df0 = df['566'].append(df['1']).append(df['2']).append(df['3']).append(df['4']).append(df['5']).append(df['6']).append(df['7']).append(df['8'])

# %%
df0.dropna()
# Out:
# 0                               Haye veneve hamuyambo?
# 1    Ukipacha nchu eyavo Lamu mpe hao isi anechee nami
# 6                              Machunda yote yandovowa
# 7                         Chakula kindoiva vidhuri yeo
# 8                         Mwana vao ni mchukuchu dhana
#                            ...
# 0                                        Wote wadhima?
# 0                                    Nasi hachuyaambo?
# 0                                     Twashkuru Mungu?
# 0    Yana tundakwenda spichali kumvenga mame, tukin...
# 0           Daktari menena mame afungwe mai tupa mbili
# Length: 566, dtype: object
